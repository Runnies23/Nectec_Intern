# %%
# !pip install rank_bm25 pythainlp
import os  
try : 
    print("Try to import")
    #from rank_bm25 import BM25Okapi
   # from pythainlp.tokenize import word_tokenize
    import requests
    import pandas as pd 
    import json
    from tqdm import tqdm
except:
    print("Download Env")
    #os.system("pip install rank_bm25 pythainlp pandas")
    from pythainlp.tokenize import word_tokenize
    import pandas as pd 
    import requests
    from rank_bm25 import BM25Okapi
    from tqdm import tqdm
print("Done Import")
# Out:
# Try to import
# Done Import

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\asus\anaconda3\lib\site-packages (4.66.4)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
def QueryTyphoon_70b(Prompt,device='cuda',token=512,temp=0.3):
    endpoint = 'https://api.opentyphoon.ai/v1/chat/completions'
    res = requests.post(endpoint, json={
        "model": "typhoon-v1.5-instruct",
        "max_tokens": token,
        "messages": [{"content": Prompt ,"role":"user"}],
        "temperature": temp,
        "top_p": 0.9,
        "top_k": 0,
        "repetition_penalty": 1.05,
        "min_p": 0.05
    }, headers={
        "Authorization": "Bearer sk-9XgeBejZ3oluCmuxKJlOHfsZ2H5arkm4INeogIEC17bz4GC8",
    })
    data = res.json()
    queries = data["choices"][0]["message"]["content"]
    # queries = queries.replace("%d.","")
    return queries

# %%
Corpus = ['Python1',
          'Python2',
          'Python3']

# %%
Query_Topic = 'เรียนPython'

# %%
BM25 = []
Questionlist = []
tokenized_corpus = [word_tokenize(doc, engine="newmm") for doc in Corpus]

bm25 = BM25Okapi(tokenized_corpus)

# %%
# for i in Question:
#   query = i
tokenized_query = word_tokenize(Query_Topic, engine="newmm")
doc_scores = bm25.get_scores(tokenized_query)
ans = bm25.get_top_n(tokenized_query,Corpus, n=1)
print(doc_scores)
Questionlist.append(Query_Topic)
BM25.append(ans)
print(f"{Query_Topic},{ans}")
# Out:
# [-0.02583958 -0.02583958 -0.02583958]
# เรียนPython,['Python3']

# %%
#Task 
Personal = "ผู้ช่วยจัดการแผนงานที่คอยดูว่าสิ่งที่ผู้ใช้ต้องการทำเป็นไปได้หรือไม่ถ้าเป็นไปไม่ได้คุณจะหาเส้นทางที่จะทำให้มันเป็นไปได้ไม่ว่ายังไงก็ตาม"
Topics = "สร้างเเชทGPT"
Time = "24ชั่วโมง"
Prompt_Task2_1 = f"""
You are a greatest teacher for create 10 exercises question, Your work to create a 10 question for test student who plan to {Topics} to Level measurement knowledge of this student that what level there he is.
The Detail about question for meansure student
You need to follow these 3 Rule 
1.You have to create 10 questino and then return me with Format that I give below
2. that question is about {Topics}
3. Do not Answer the tile of this about just only return of question that you created
```
1. (Question1)
2. (Question2)
.
.
.
10. (Question10)
```
"""
print(Prompt_Task2_1)
# Out:
# You are a greatest teacher for create 10 exercises question, Your work to create a 10 question for test student who plan to สร้างเเชทGPT to Level measurement knowledge of this student that what level there he is.
# The Detail about question for meansure student
# You need to follow these 3 Rule
# 1.You have to create 10 questino and then return me with Format that I give below
# 2. that question is about สร้างเเชทGPT
# 3. Do not Answer the tile of this about just only return of question that you created
# ```
# 1. (Question1)
# 2. (Question2)
# .
# .
# .
# 10. (Question10)
# ```

# %%
query_task2_1 = QueryTyphoon_70b(Prompt_Task2_1,temp=0.6)
print(query_task2_1)
# Out:
# 1. (Question1) What is the primary purpose of using a transformer in a GPT-3 style language model?
# 2. (Question2) How does the concept of autoregressive modeling apply to the generation of text in a GPT-3 chatbot?
# 3. (Question3) What is the role of the context window in processing input text for a GPT-3 based chatbot?
# 4. (Question4) Explain the difference between the discrete and continuous vocabulary sampling techniques used in GPT-3 models.
# 5. (Question5) How does the GPT-3 model handle out-of-vocabulary words during text generation?
# 6. (Question6) Describe the process of fine-tuning a pre-trained GPT-3 model for a specific domain or task.
# 7. (Question7) What are some potential limitations of using a GPT-3 style language model for creating a conversational AI?
# 8. (Question8) How can we evaluate the performance of a GPT-3 based chatbot in terms of its fluency, coherence, and relevance?
# 9. (Question9) Discuss the ethical considerations and potential misuse of GPT-3 technology in developing chatbots.
# 10. (Question10) How can we integrate GPT-3 models with other AI technologies, such as computer vision or natural language understanding, to create more sophisticated applications?

# %%
def ReturnPrompt(query_task2_1,Topic=Topics):
    Prompt_Task2_2 = f"""
    You are a greatest teacher for create 10 exercises, Your work to create translate question that i give and create a Choice in 10 question for test student who plan to {Topic} to Level measurement knowledge of this student that what level there he is. You have a skill that know 2 language in english and thai language and you very good at it 
    The Detail about question for meansure student So I have 5 Rule you should follow: 
    1. I have a 10 question that you need to traslate to Thai language and then create choice that in thai langguage with Json Format (I give below)
    2. that question is about {Topic}
    3. In each question have 4 choice and 3 each choice is a correct answer,expect 1 choice So there all 3 choice each will have a personal point like 0.25 0.5 and 0.75 and store in tuple and in Choice1-4 in Choice
    4. **This is priority number1** question and choice that create gonna be in Thai language
    write the Answer only in the Json format and English Language, Do not add the Title what is this Json for 

    Here is a 10 question that you gonna translate and create choice 
    ```
    {query_task2_1}
    ```
    {{
    'Question1' : {{'Question' : (q1),
                        'Choice' : {{
                            'Choice1' : [
                                (c1)
                                ,(weight point1)
                                ],
                            'Choice2' : [
                                (c2)
                                ,(weight point2)
                                ],
                            'Choice3' : [
                                (c3)
                                ,(weight point3)
                                ],
                            'Choice4' : [
                                (c4)
                                ,(weight point4)
                                ],
                                }}
                        }},
        ```
        Repeat this untill 10 question
        ```
    }}
    I warning you again that all the question and answer gonna be in Thai language
    """
    return Prompt_Task2_2
# print(Prompt_Task2_2)

# %%
# df = pd.DataFrame(columns=['Question', 'Choice1', 'Choice2', 'Choice3', 'Choice4'])
for i in tqdm(range(10)):
    #query_task2_1 = QueryTyphoon_70b(Prompt_Task2_1,temp=0.6)
    query_task2_1 = QueryTyphoon_70b(Prompt_Task2_1,temp=0.6)
    Prompt_Task2_2 = ReturnPrompt(query_task2_1)
    query_task2_2 = QueryTyphoon_70b(Prompt_Task2_2,token=2000,temp=0.6)
    query_task2_2_json = json.loads(query_task2_2.replace("'",'"'))
    query_task2_2_json
    rows = []
    for q_key, q_value in query_task2_2_json.items():
        question = q_value['Question']
        choices = q_value['Choice']
        
        row = {
            'Question': question,
            'Choice1': (choices['Choice1'][0], choices['Choice1'][1]),
            'Choice2': (choices['Choice2'][0], choices['Choice2'][1]),
            'Choice3': (choices['Choice3'][0], choices['Choice3'][1]),
            'Choice4': (choices['Choice4'][0], choices['Choice4'][1]),
        }
        rows.append(row)

    df_task2 = pd.DataFrame(rows)
    df = pd.concat([df,df_task2])
# Out:
#   0%|          | 0/10 [00:23<?, ?it/s]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[12], line 7
#       5 Prompt_Task2_2 = ReturnPrompt(query_task2_1)
#       6 query_task2_2 = QueryTyphoon_70b(Prompt_Task2_2,token=2000,temp=0.6)
# ----> 7 query_task2_2_json = json.loads(query_task2_2.replace("'",'"'))
#       8 query_task2_2_json
#       9 rows = []
#
# File c:\Users\ASUS\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\ASUS\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\ASUS\anaconda3\Lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 211 column 2 (char 3415)

# %%
print(query_task2_2.replace("'",'"'))
# Out:
# {
# "Question1" : {"Question" : "GPT (Generative Pretrained Transformer) มีหน้าที่หลักอย่างไรในการประมวลผลภาษาธรรมชาติ?",
#                 "Choice" : {
#                     "Choice1" : ["สร้างโมเดลภาษาที่สามารถเข้าใจและสร้างข้อความได้", 0.75],
#                     "Choice2" : ["ประมวลผลข้อมูลภาษาเพื่อหาความสัมพันธ์ระหว่างคำ", 0.5],
#                     "Choice3" : ["แปลงข้อมูลภาษาเป็นรูปแบบที่เครื่องจักรสามารถเข้าใจได้", 0.25],
#                     "Choice4" : ["วิเคราะห์ข้อมูลภาพและเสียง", 0]
#                     }
#                 },
# "Question2" : {"Question" : "โมเดล GPT แตกต่างจากโครงสร้างเครือข่ายประสาทแบบดั้งเดิมอย่างไรในด้านกลไกการให้ความสนใจ?",
#                 "Choice" : {
#                     "Choice1" : ["ใช้กลไกการให้ความสนใจแบบหลายชั้น", 0.75],
#                     "Choice2" : ["ไม่จำเป็นต้องมีการกำหนดค่าเริ่มต้นของโมเดล", 0.5],
#                     "Choice3" : ["สามารถประมวลผลข้อมูลภาษาได้อย่างรวดเร็ว", 0.25],
#                     "Choice4" : ["ไม่สามารถประมวลผลข้อมูลภาษาได้", 0]
#                     }
#                 },
# "Question3" : {"Question" : "บทบาทของการฝึกอบรมล่วงหน้าในโมเดล GPT คืออะไร และมันช่วยให้โมเดลทำงานได้ดียิ่งขึ้นในการทำภารกิจต่อไปอย่างไร?",
#                 "Choice" : {
#                     "Choice1" : ["ช่วยให้โมเดลสามารถเข้าใจภาษาได้ดียิ่งขึ้น", 0.75],
#                     "Choice2" : ["ทำให้โมเดลสามารถปรับตัวได้กับข้อมูลใหม่ๆ", 0.5],
#                     "Choice3" : ["ช่วยลดเวลาในการฝึกอบรมโมเดล", 0.25],
#                     "Choice4" : ["ไม่มีผลกระทบใดๆ ต่อโมเดล", 0]
#                     }
#                 },
# "Question4" : {"Question" : "ในโครงสร้าง GPT, บล็อกdecoder มีไว้เพื่ออะไร และมันทำงานร่วมกับบล็อกencoder อย่างไร?",
#                 "Choice" : {
#                     "Choice1" : ["สร้างข้อความจากข้อมูลที่ได้รับ", 0.75],
#                     "Choice2" : ["แปลงข้อมูลภาษาเป็นรูปแบบที่เครื่องจักรสามารถเข้าใจได้", 0.5],
#                     "Choice3" : ["ประมวลผลข้อมูลภาษาเพื่อหาความสัมพันธ์ระหว่างคำ", 0.25],
#                     "Choice4" : ["ไม่มีบทบาทใดๆ ในโครงสร้าง GPT", 0]
#                     }
#                 },
# "Question5" : {"Question" : "โมเดล GPT จัดการกับคำที่ไม่ได้อยู่ในคลังศัพท์ (out-of-vocabulary words) อย่างไรในการสร้างข้อความ?",
#                 "Choice" : {
#                     "Choice1" : ["ใช้เทคนิคการแทนคำด้วยคำที่ใกล้เคียง", 0.75],
#                     "Choice2" : ["ใช้เทคนิคการสร้างคำใหม่จากคำที่มีอยู่", 0.5],
#                     "Choice3" : ["ละเว้นคำที่ไม่ได้อยู่ในคลังศัพท์", 0.25],
#                     "Choice4" : ["ไม่สามารถจัดการกับคำที่ไม่ได้อยู่ในคลังศัพท์", 0]
#                     }
#                 },
# "Question6" : {"Question" : "ความแตกต่างระหว่าง GPT-1, GPT-2, และ GPT-3 คืออะไรในด้านขนาดโมเดล, ข้อมูลการฝึกอบรม, และความสามารถ?",
#                 "Choice" : {
#                     "Choice1" : ["GPT-3 มีขนาดโมเดลใหญ่ที่สุดและมีความสามารถมากที่สุด", 0.75],
#                     "Choice2" : ["GPT-1 มีข้อมูลการฝึกอบรมน้อยที่สุด", 0.5],
#                     "Choice3" : ["GPT-2 มีขนาดโมเดลกลางและมีความสามารถปานกลาง", 0.25],
#                     "Choice4" : ["ทั้งหมดเท่ากัน", 0]
#                     }
#                 },
# "Question7" : {"Question" : "โมเดล GPT จัดการกับความสัมพันธ์ที่ยาวนานในข้อมูลภาษาเข้าอย่างไร และมีเทคนิคใดๆ ที่ใช้เพื่อปรับปรุงประสิทธิภาพในด้านนี้?",
#                 "Choice" : {
#                     "Choice1" : ["ใช้เทคนิคการให้ความสนใจแบบหลายชั้น", 0.75],
#                     "Choice2" : ["ใช้เทคนิคการประมวลผลข้อมูลภาษาแบบไม่ต่อเนื่อง", 0.5],
#                     "Choice3" : ["ใช้เทคนิคการสร้างโมเดลภาษาที่สามารถเข้าใจความสัมพันธ์ระหว่างคำ", 0.25],
#                     "Choice4" : ["ไม่สามารถจัดการกับความสัมพันธ์ที่ยาวนาน", 0]
#                     }
#                 },
# "Question8" : {"Question" : "คุณสามารถอธิบายแนวคิดของการสร้างโมเดลลักษณะภาษา (masked language modeling) ในบริบทของการฝึกอบรม GPT และวิธีที่มันช่วยให้โมเดลเรียนรู้การแสดงออกภาษาที่มีความหมายอย่างไร?",
#                 "Choice" : {
#                     "Choice1" : ["ช่วยให้โมเดลสามารถเรียนรู้ความสัมพันธ์ระหว่างคำ", 0.75],
#                     "Choice2" : ["ช่วยให้โมเดลสามารถเข้าใจภาษาได้ดียิ่งขึ้น", 0.5],
#                     "Choice3" : ["ช่วยลดเวลาในการฝึกอบรมโมเดล", 0.25],
#                     "Choice4" : ["ไม่มีผลกระทบใดๆ ต่อโมเดล", 0]
#                     }
#                 },
# "Question9" : {"Question" : "มีการประยุกต์ใช้เทคโนโลยี GPT อย่างไรในสถานการณ์จริง เช่น แชทบอทหรือการสร้างเนื้อหา?",
#                 "Choice" : {
#                     "Choice1" : ["ใช้สร้างแชทบอทที่สามารถตอบคำถามของผู้ใช้ได้", 0.75],
#                     "Choice2" : ["ใช้สร้างเนื้อหาที่มีคุณภาพสูง", 0.5],
#                     "Choice3" : ["ใช้ประมวลผลข้อมูลภาษาเพื่อหาความสัมพันธ์ระหว่างคำ", 0.25],
#                     "Choice4" : ["ไม่มีการประยุกต์ใช้ใดๆ", 0]
#                     }
#                 },
# "Question10" : {"Question" : "คุณสามารถปรับปรุงโมเดล GPT ที่ถูกฝึกอบรมล่วงหน้าให้เหมาะสมกับภารกิจเฉพาะ เช่น การวิเคราะห์ความรู้สึกหรือการตอบคำถามอย่างไร?",
#                 "Choice" : {
#                     "Choice1" : ["ใช้เทคนิคการฝึกอบรมโมเดลใหม่ด้วยข้อมูลที่เฉพาะเจาะจง", 0.75],
#                     "Choice2" : ["ปรับเปลี่ยนพารามิเตอร์ของโมเดลให้เหมาะสมกับภารกิจ", 0.5],
#                     "Choice3" : ["ใช้เท

# %%
df.to_csv("save/100_question_2.csv",index=False)

# %%
df = pd.DataFrame(columns=['Question', 'Choice1', 'Choice2', 'Choice3', 'Choice4'])
df
# Out:
#                                             Question  \
# 0  การสร้างเเชทบอท GPT มีเป้าหมายหลักอย่างไร และแ...
# 1  โมเดล GPT ใช้การฝึกอบรมและการปรับแต่งอย่างละเอ...
# 2  บทบาทของการจำลองภาษาที่ปกปิดในกระบวนการฝึกอบรม...
# 3  กลไกการให้ความสำคัญในทรานส์ฟอร์เมอร์และความสำค...
# 4  GPT จัดการกับคำหรือโทเค็นที่ไม่มีอยู่ในพจนานุก...
# 5  เปรียบเทียบและต่างกันระหว่างโมเดล GPT-1, GPT-2...
# 6  อภิปรายถึงความเสี่ยงและข้อพิจารณาทางจริยธรรมที...
# 7  บรรยายสถานการณ์ที่ GPT สามารถนำไปใช้ในการสร้าง...
# 8  การเรียนรู้แบบเสริมแรงสามารถผสมผสานกับ GPT อย่...
# 9  เมตริกการประเมินผลทั่วไปที่ใช้ในการประเมินประส...
# 0  การสร้างเเชทบอท GPT มีเป้าหมายหลักอย่างไร และแ...
# 1  โมเดล GPT ใช้การฝึกอบรมและการปรับแต่งอย่างละเอ...
# 2  บทบาทของการจำลองภาษาที่ปกปิดในกระบวนการฝึกอบรม...
# 3  กลไกการให้ความสำคัญในทรานส์ฟอร์เมอร์และความสำค...
# 4  GPT จัดการกับคำหรือโทเค็นที่ไม่มีอยู่ในพจนานุก...
# 5  เปรียบเทียบและต่างกันระหว่างโมเดล GPT-1, GPT-2...
# 6  อภิปรายถึงความเสี่ยงและข้อพิจารณาทางจริยธรรมที...
# 7  บรรยายสถานการณ์ที่ GPT สามารถนำไปใช้ในการสร้าง...
# 8  การเรียนรู้แบบเสริมแรงสามารถผสมผสานกับ GPT อย่...
# 9  เมตริกการประเมินผลทั่วไปที่ใช้ในการประเมินประส...
# 0  การสร้างเเชทบอท GPT มีเป้าหมายหลักอย่างไร และแ...
# 1  โมเดล GPT ใช้การฝึกอบรมและการปรับแต่งอย่างละเอ...
# 2  บทบาทของการจำลองภาษาที่ปกปิดในกระบวนการฝึกอบรม...
# 3  กลไกการให้ความสำคัญในทรานส์ฟอร์เมอร์และความสำค...
# 4  GPT จัดการกับคำหรือโทเค็นที่ไม่มีอยู่ในพจนานุก...
# 5  เปรียบเทียบและต่างกันระหว่างโมเดล GPT-1, GPT-2...
# 6  อภิปรายถึงความเสี่ยงและข้อพิจารณาทางจริยธรรมที...
# 7  บรรยายสถานการณ์ที่ GPT สามารถนำไปใช้ในการสร้าง...
# 8  การเรียนรู้แบบเสริมแรงสามารถผสมผสานกับ GPT อย่...
# 9  เมตริกการประเมินผลทั่วไปที่ใช้ในการประเมินประส...
#
#                                         Choice1  \
# 0       (เพื่อสร้างความสัมพันธ์กับผู้ใช้, 0.25)
# 1                  (การใช้ข้อมูลขนาดใหญ่, 0.25)
# 2   (เพื่อสร้างความสามารถในการเข้าใจภาษา, 0.25)
# 3   (เพื่อสร้างความสามารถในการเข้าใจภาษา, 0.25)
# 4                (การใช้เทคนิคการฝึกอบรม, 0.25)
# 5                   (GPT-1 มีขนาดเล็กสุด, 0.25)
# 6  (ความเสี่ยงในการละเมิดความเป็นส่วนตัว, 0.25)
# 7           (การใช้ GPT ในการสร้างบทความ, 0.25)
# 8                      (การใช้การฝึกอบรม, 0.25)
# 9                     (การใช้เมตริก BLEU, 0.25)
# 0       (เพื่อสร้างความสัมพันธ์กับผู้ใช้, 0.25)
# 1                  (การใช้ข้อมูลขนาดใหญ่, 0.25)
# 2   (เพื่อสร้างความสามารถในการเข้าใจภาษา, 0.25)
# 3   (เพื่อสร้างความสามารถในการเข้าใจภาษา, 0.25)
# 4                (การใช้เทคนิคการฝึกอบรม, 0.25)
# 5                   (GPT-1 มีขนาดเล็กสุด, 0.25)
# 6  (ความเสี่ยงในการละเมิดความเป็นส่วนตัว, 0.25)
# 7           (การใช้ GPT ในการสร้างบทความ, 0.25)
# 8                      (การใช้การฝึกอบรม, 0.25)
# 9                     (การใช้เมตริก BLEU, 0.25)
# 0       (เพื่อสร้างความสัมพันธ์กับผู้ใช้, 0.25)
# 1                  (การใช้ข้อมูลขนาดใหญ่, 0.25)
# 2   (เพื่อสร้างความสามารถในการเข้าใจภาษา, 0.25)
# 3   (เพื่อสร้างความสามารถในการเข้าใจภาษา, 0.25)
# 4                (การใช้เทคนิคการฝึกอบรม, 0.25)
# 5                   (GPT-1 มีขนาดเล็กสุด, 0.25)
# 6  (ความเสี่ยงในการละเมิดความเป็นส่วนตัว, 0.25)
# 7           (การใช้ GPT ในการสร้างบทความ, 0.25)
# 8                      (การใช้การฝึกอบรม, 0.25)
# 9                     (การใช้เมตริก BLEU, 0.25)
#
#                                            Choice2  \
# 0          (เพื่อสร้างข้อความที่เหมือนมนุษย์, 0.5)
# 1                    (การใช้เทคนิคการฝึกอบรม, 0.5)
# 2     (เพื่อสร้างความสามารถในการสร้างข้อความ, 0.5)
# 3     (เพื่อสร้างความสามารถในการสร้างข้อความ, 0.5)
# 4                      (การใช้ข้อมูลขนาดใหญ่, 0.5)
# 5         (GPT-2 มีข้อมูลการฝึกอบรมมากที่สุด, 0.5)
# 6  (ความเสี่ยงในการสร้างข้อความที่ไม่เหมาะสม, 0.5)
# 7                 (การใช้ GPT ในการสร้างเพลง, 0.5)
# 8             (การใช้การปรับแต่งอย่างละเอียด, 0.5)
# 9                        (การใช้เมตริก ROUGE, 0.5)
# 0          (เพื่อสร้างข้อความที่เหมือนมนุษย์, 0.5)
# 1                    (การใช้เทคนิคการฝึกอบรม, 0.5)
# 2     (เพื่อสร้างความสามารถในการสร้างข้อความ, 0.5)
# 3     (เพื่อสร้างความสามารถในการสร้างข้อความ, 0.5)
# 4                      (การใช้ข้อมูลขนาดใหญ่, 0.5)
# 5         (GPT-2 มีข้อมูลการฝึกอบรมมากที่สุด, 0.5)
# 6  (ความเสี่ยงในการสร้างข้อความที่ไม่เหมาะสม, 0.5)
# 7                 (การใช้ GPT ในการสร้างเพลง, 0.5)
# 8             (การใช้การปรับแต่งอย่างละเอียด, 0.5)
# 9                        (การใช้เมตริก ROUGE, 0.5)
# 0          (เพื่อสร้างข้อความที่เหมือนมนุษย์, 0.5)
# 1                    (การใช้เทคนิคการฝึกอบรม, 0.5)
# 2     (เพื่อสร้างความสามารถในการสร้างข้อความ, 0.5)
# 3     (เพื่อสร้างความสามารถในการสร้างข้อความ, 0.5)
# 4                      (การใช้ข้อมูลขนาดใหญ่, 0.5)
# 5         (GPT-2 มีข้อมูลการฝึกอบรมมากที่สุด, 0.5)
# 6  (ความเสี่ยงในการสร้างข้อความที่ไม่เหมาะสม, 0.5)
# 7                 (การใช้ GPT ในการสร้างเพลง, 0.5)
# 8             (การใช้การปรับแต่งอย่างละเอียด, 0.5)
# 9                        (การใช้เมตริก ROUGE, 0.5)
#
#                                              Choice3  \
# 0              (เพื่อทำความเข้าใจภาษาธรรมชาติ, 0.75)
# 1              (การใช้การปรับแต่งอย่างละเอียด, 0.75)
# 2        (เพื่อสร้างความสามารถในการจำแนกบริบท, 0.75)
# 3        (เพื่อสร้างความสามารถในการจำแนกบริบท, 0.75)
# 4              (การใช้การปรับแต่งอย่างละเอียด, 0.75)
# 5  (GPT-3 มีความสามารถในการสร้างข้อความที่ดีที่สุ...
# 6          (ความเสี่ยงในการสร้างความเข้าใจผิด, 0.75)
# 7                   (การใช้ GPT ในการสร้างภาพ, 0.75)
# 8          (การใช้ AI เพื่อปรับปรุงการตอบสนอง, 0.75)
# 9                        (การใช้เมตริก METEOR, 0.75)
# 0              (เพื่อทำความเข้าใจภาษาธรรมชาติ, 0.75)
# 1              (การใช้การปรับแต่งอย่างละเอียด, 0.75)
# 2        (เพื่อสร้างความสามารถในการจำแนกบริบท, 0.75)
# 3        (เพื่อสร้างความสามารถในการจำแนกบริบท, 0.75)
# 4              (การใช้การปรับแต่งอย่างละเอียด, 0.75)
# 5  (GPT-3 มีความสามารถในการสร้างข้อความที่ดีที่สุ...
# 6          (ความเสี่ยงในการสร้างความเข้าใจผิด, 0.75)
# 7                   (การใช้ GPT ในการสร้างภาพ, 0.75)
# 8          (การใช้ AI เพื่อปรับปรุงการตอบสนอง, 0.75)
# 9                        (การใช้เมตริก METEOR, 0.75)
# 0              (เพื่อทำความเข้าใจภาษาธรรมชาติ, 0.75)
# 1              (การใช้การปรับแต่งอย่างละเอียด, 0.75)
# 2        (เพื่อสร้างความสามารถในการจำแนกบริบท, 0.75)
# 3        (เพื่อสร้างความสามารถในการจำแนกบริบท, 0.75)
# 4              (การใช้การปรับแต่งอย่างละเอียด, 0.75)
# 5  (GPT-3 มีความสามารถในการสร้างข้อความที่ดีที่สุ...
# 6          (ความเสี่ยงในการสร้างความเข้าใจผิด, 0.75)
# 7                   (การใช้ GPT ในการสร้างภาพ, 0.75)
# 8          (การใช้ AI เพื่อปรับปรุงการตอบสนอง, 0.75)
# 9                        (การใช้เมตริก METEOR, 0.75)
#
#                                   Choice4
# 0                   (เพื่อสร้างรายได้, 0)
# 1          (การใช้ AI เพียงอย่างเดียว, 0)
# 2   (เพื่อสร้างความสามารถในการจำแนกคำ, 0)
# 3   (เพื่อสร้างความสามารถในการจำแนกคำ, 0)
# 4          (การใช้ AI เพียงอย่างเดียว, 0)
# 5  (ทั้งหมดมีขนาดและความสามารถเท่ากัน, 0)
# 6                 (ไม่มีความเสี่ยงใดๆ, 0)
# 7      (การใช้ GPT ในการสร้างภาพยนตร์, 0)
# 8               (การใช้ข้อมูลขนาดใหญ่, 0)
# 9                   (การใช้เมตริก WMD, 0)
# 0                   (เพื่อสร้างรายได้, 0)
# 1          (การใช้ AI เพียงอย่างเดียว, 0)
# 2   (เพื่อสร้างความสามารถในการจำแนกคำ, 0)
# 3   (เพื่อสร้างความสามารถในการจำแนกคำ, 0)
# 4          (การใช้ AI เพียงอย่างเดียว, 0)
# 5  (ทั้งหมดมีขนาดและความสามารถเท่ากัน, 0)
# 6                 (ไม่มีความเสี่ยงใดๆ, 0)
# 7      (การใช้ GPT ในการสร้างภาพยนตร์, 0)
# 8               (การใช้ข้อมูลขนาดใหญ่, 0)
# 9                   (การใช้เมตริก WMD, 0)
# 0                   (เพื่อสร้างรายได้, 0)
# 1          (การใช้ AI เพียงอย่างเดียว, 0)
# 2   (เพื่อสร้างความสามารถในการจำแนกคำ, 0)
# 3   (เพื่อสร้างความสามารถในการจำแนกคำ, 0)
# 4          (การใช้ AI เพียงอย่างเดียว, 0)
# 5  (ทั้งหมดมีขนาดและความสามารถเท่ากัน, 0)
# 6                 (ไม่มีความเสี่ยงใดๆ, 0)
# 7      (การใช้ GPT ในการสร้างภาพยนตร์, 0)
# 8               (การใช้ข้อมูลขนาดใหญ่, 0)
# 9                   (การใช้เมตริก WMD, 0)
