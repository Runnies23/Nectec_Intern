# %%
import os 
import json
try: 
    import torch
    import pandas as pd 
    import requests
except:
    os.system('pip install torch pandas requests')

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

def ReturnJsonFormat(Text_Json_format,replace=False):
    if replace:
        Text_Json_format = Text_Json_format.replace("'",'"').replace('[','}').replace(']','}')
    Text_Json_format = Text_Json_format.replace("'",'"')
    return json.loads(Text_Json_format)

#Typhoon API typhoon-v1.5x-70b-instruct
#Huggingface Model "scb10x/llama-3-typhoon-v1.5x-70b-instruct"
def QueryTyphoon_70b(Prompt,device='cuda'):
    endpoint = 'https://api.opentyphoon.ai/v1/chat/completions'
    res = requests.post(endpoint, json={
        "model": "typhoon-v1.5x-70b-instruct",
        "max_tokens": 1536,
        "messages":  [{"content": Prompt ,"role":"user"}],
        "temperature": 0.3,
        "top_p": 0.9,
        "top_k": 0,
        "repetition_penalty": 1.05,
        "min_p": 0
    }, headers={
        "Authorization": "Bearer sk-GJSNUB7gZTUIwXCkAX2zkJJeaMhwDBcHjz2xt63jW3u9xKEu",
    })
    data = res.json()
    queries = data["choices"][0]["message"]["content"]
    queries = queries.replace("%d.","")
    return queries
# Out:
# Using device: cuda

# %%
Topic = "create a chat gpt"
Persona = "greatest planner teacher for student learning"
Time = "24 hour"
#==========================================================================

Prompt = f"""
You are a greatest teacher for create 10 exercises, Your work to create a 10 question for test student who plan to {Topic} to Level measurement knowledge of this student that what level there he is
The Detail about question for meansure student is 
1. create a 10 question with Json (I give below)
2. that question is about {Topic}
3. In each question have 4 choice and 3 each choice is a correct answer,expect 1 choice So there all 3 choice each will have a personal point like 0.25 0.5 and 0.75
write the Answer only in the Json format and English Language, Do not add the Title what is this Json for 
{{
'Question1' : {{{{'Question' : (q1),
                    'Choice' : [
                        'Choice1' : [
                            (c1)
                            ,(weight point1)
                            ],
                        'Choice2' : [
                            (c2)
                            ,(weight point2)
                            ],
                        'Choice3' : [
                            (c3)
                            ,(weight point3)
                            ],
                        'Choice4' : [
                            (c4)
                            ,(weight point4)
                            ],
                    }}}},
                    
'Question2' : {{{{'Question' : (q2),
                    'Choice' : [
                        'Choice1' : [
                            (c1)
                            ,(weight point1)
                            ],
                        'Choice2' : [
                            (c2)
                            ,(weight point2)
                            ],
                        'Choice3' : [
                            (c3)
                            ,(weight point3)
                            ],
                        'Choice4' : [
                            (c4)
                            ,(weight point4)
                            ],
                    }}}},
}}
"""
print(Prompt)
# Out:
# You are a greatest teacher for create 10 exercises, Your work to create a 10 question for test student who plan to create a chat gpt to Level measurement knowledge of this student that what level there he is
# The Detail about question for meansure student is
# 1. create a 10 question with Json (I give below)
# 2. that question is about create a chat gpt
# 3. In each question have 4 choice and 3 each choice is a correct answer,expect 1 choice So there all 3 choice each will have a personal point like 0.25 0.5 and 0.75
# 4. question and choice that create gonna be in Thai language
# write the Answer only in the Json format and English Language, Do not add the Title what is this Json for
# {
# 'Question1' : {{'Question' : (q1),
#                     'Choice' : [
#                         'Choice1' : [
#                             (c1)
#                             ,(weight point1)
#                             ],
#                         'Choice2' : [
#                             (c2)
#                             ,(weight point2)
#                             ],
#                         'Choice3' : [
#                             (c3)
#                             ,(weight point3)
#                             ],
#                         'Choice4' : [
#                             (c4)
#                             ,(weight point4)
#                             ],
#                     }},
#
# 'Question2' : {{'Question' : (q2),
#                     'Choice' : [
#                         'Choice1' : [
#                             (c1)
#                             ,(weight point1)
#                             ],
#                         'Choice2' : [
#                             (c2)
#                             ,(weight point2)
#                             ],
#                         'Choice3' : [
#                             (c3)
#                             ,(weight point3)
#                             ],
#                         'Choice4' : [
#                             (c4)
#                             ,(weight point4)
#                             ],
#                     }},
# }

# %%
Answer = QueryTyphoon_70b(Prompt) #Query 1 
try:
    Query_Response = ReturnJsonFormat(Answer,replace=False)
except:
    print("😣😣😣😣Error😣😣😣😣")
    print(Answer)

# %%
rows = []
for q_key, q_value in Query_Response.items():
    question = q_value['Question']
    choices = q_value['Choice']
    
    row = {
        'Question': question,
        'Choice1': (choices['Choice1'][0], choices['Choice1'][1]),
        'Choice2': (choices['Choice2'][0], choices['Choice2'][1]),
        'Choice3': (choices['Choice3'][0], choices['Choice3'][1]),
        'Choice4': (choices['Choice4'][0], choices['Choice4'][1]),
    }
    rows.append(row)

df = pd.DataFrame(rows)
df
# Out:
#                                             Question  \
# 0   What is the primary goal of creating a chat GPT?
# 1  Which of the following is NOT a common archite...
# 2  What is the main advantage of using pre-traine...
# 3  Which of the following techniques is commonly ...
# 4   What is the purpose of tokenization in chat GPT?
# 5  Which of the following metrics is commonly use...
# 6  What is the primary challenge in developing a ...
# 7  Which of the following datasets is commonly us...
# 8  What is the primary benefit of using reinforce...
# 9  Which of the following is a potential limitati...
#
#                                              Choice1  \
# 0                (To generate human-like text, 0.75)
# 1                                 (Transformer, 0.0)
# 2                    (Faster development time, 0.75)
# 3                          (Transfer learning, 0.75)
# 4  (To convert text into numerical representation...
# 5                                 (Perplexity, 0.75)
# 6          (Handling multi-turn conversations, 0.75)
# 7                               (Common Crawl, 0.75)
# 8               (Improved response generation, 0.75)
# 9                       (Lack of common sense, 0.75)
#
#                                    Choice2  \
# 0     (To automate customer support, 0.25)
# 1   (Recurrent Neural Network (RNN), 0.25)
# 2                (Improved accuracy, 0.25)
# 3                  (Active learning, 0.25)
# 4             (To remove stop words, 0.25)
# 5                       (BLEU score, 0.25)
# 6        (Understanding user intent, 0.25)
# 7                        (Wikipedia, 0.25)
# 8        (Increased user engagement, 0.25)
# 9  (Inability to understand sarcasm, 0.25)
#
#                                      Choice3  \
# 0             (To create a sentient AI, 0.0)
# 1  (Convolutional Neural Network (CNN), 0.0)
# 2    (Reduced computational resources, 0.25)
# 3                   (Ensemble learning, 0.0)
# 4       (To perform sentiment analysis, 0.0)
# 5                        (ROUGE score, 0.25)
# 6      (Generating coherent responses, 0.25)
# 7                        (Twitter data, 0.0)
# 8               (Reduced training time, 0.0)
# 9           (Limited domain knowledge, 0.25)
#
#                                   Choice4
# 0           (To translate languages, 0.0)
# 1                   (Decision Tree, 0.75)
# 2      (Easier model interpretation, 0.0)
# 3                  (Online learning, 0.0)
# 4           (To translate languages, 0.0)
# 5                         (Accuracy, 0.0)
# 6            (Training large models, 0.0)
# 7                     (IMDB reviews, 0.0)
# 8    (Simplified model architecture, 0.0)
# 9  (High computational requirements, 0.0)
