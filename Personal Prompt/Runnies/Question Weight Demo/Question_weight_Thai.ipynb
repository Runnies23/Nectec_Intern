# %%
import os 
import json
try: 
    import torch
    import pandas as pd 
    import requests
except:
    os.system('pip install torch pandas requests')

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

def ReturnJsonFormat(Text_Json_format,replace=False):
    if replace:
        Text_Json_format = Text_Json_format.replace("'",'"').replace('[','}').replace(']','}')
    Text_Json_format = Text_Json_format.replace("'",'"')
    return json.loads(Text_Json_format)

#Typhoon API typhoon-v1.5x-70b-instruct
#Huggingface Model "scb10x/llama-3-typhoon-v1.5x-70b-instruct"
def QueryTyphoon_70b(Prompt,device='cuda'):
    endpoint = 'https://api.opentyphoon.ai/v1/chat/completions'
    res = requests.post(endpoint, json={
        "model": "typhoon-v1.5x-70b-instruct",
        "max_tokens": 1536,
        "messages":  [{"content": Prompt ,"role":"user"}],
        "temperature": 0.3,
        "top_p": 0.9,
        "top_k": 0,
        "repetition_penalty": 1.05,
        "min_p": 0
    }, headers={
        "Authorization": "Bearer sk-GJSNUB7gZTUIwXCkAX2zkJJeaMhwDBcHjz2xt63jW3u9xKEu",
    })
    data = res.json()
    queries = data["choices"][0]["message"]["content"]
    queries = queries.replace("%d.","")
    return queries
# Out:
# Using device: cuda

# %%
Topic = "สร้างเเชท Gpt"
Persona = "greatest planner teacher for student learning"
Time = "24 ชั่วโมง"
#==========================================================================

Prompt = f"""
You are a greatest teacher for create 10 exercises, Your work to create a 10 question for test student who plan to {Topic} to Level measurement knowledge of this student that what level there he is. You have a skill that know 2 language in english and thai language and you very good at it 
The Detail about question for meansure student is 
1. create a 10 question with Json (I give below)
2. that question is about {Topic}
3. In each question have 4 choice and 3 each choice is a correct answer,expect 1 choice So there all 3 choice each will have a personal point like 0.25 0.5 and 0.75
4. **This is priority number1** question and choice that create gonna be in Thai language
write the Answer only in the Json format and English Language, Do not add the Title what is this Json for 
{{
'Question1' : {{{{'Question' : (q1),
                    'Choice' : [
                        'Choice1' : [
                            (c1)
                            ,(weight point1)
                            ],
                        'Choice2' : [
                            (c2)
                            ,(weight point2)
                            ],
                        'Choice3' : [
                            (c3)
                            ,(weight point3)
                            ],
                        'Choice4' : [
                            (c4)
                            ,(weight point4)
                            ],
                    }}}},
                    
'Question2' : {{{{'Question' : (q2),
                    'Choice' : [
                        'Choice1' : [
                            (c1)
                            ,(weight point1)
                            ],
                        'Choice2' : [
                            (c2)
                            ,(weight point2)
                            ],
                        'Choice3' : [
                            (c3)
                            ,(weight point3)
                            ],
                        'Choice4' : [
                            (c4)
                            ,(weight point4)
                            ],
                    }}}},
}}
I warning you again that all the question and answer gonna be in Thai language
"""
print(Prompt)
# Out:
# You are a greatest teacher for create 10 exercises, Your work to create a 10 question for test student who plan to สร้างเเชท Gpt to Level measurement knowledge of this student that what level there he is. You have a skill that know 2 language in english and thai language and you very good at it
# The Detail about question for meansure student is
# 1. create a 10 question with Json (I give below)
# 2. that question is about สร้างเเชท Gpt
# 3. In each question have 4 choice and 3 each choice is a correct answer,expect 1 choice So there all 3 choice each will have a personal point like 0.25 0.5 and 0.75
# 4. **This is priority number1** question and choice that create gonna be in Thai language
# write the Answer only in the Json format and English Language, Do not add the Title what is this Json for
# {
# 'Question1' : {{'Question' : (q1),
#                     'Choice' : [
#                         'Choice1' : [
#                             (c1)
#                             ,(weight point1)
#                             ],
#                         'Choice2' : [
#                             (c2)
#                             ,(weight point2)
#                             ],
#                         'Choice3' : [
#                             (c3)
#                             ,(weight point3)
#                             ],
#                         'Choice4' : [
#                             (c4)
#                             ,(weight point4)
#                             ],
#                     }},
#
# 'Question2' : {{'Question' : (q2),
#                     'Choice' : [
#                         'Choice1' : [
#                             (c1)
#                             ,(weight point1)
#                             ],
#                         'Choice2' : [
#                             (c2)
#                             ,(weight point2)
#                             ],
#                         'Choice3' : [
#                             (c3)
#                             ,(weight point3)
#                             ],
#                         'Choice4' : [
#                             (c4)
#                             ,(weight point4)
#                             ],
#                     }},
# }
# I warning you again that all the question and answer gonna be in Thai language

# %%
Answer = QueryTyphoon_70b(Prompt) #Query 1 
try:
    Query_Response = ReturnJsonFormat(Answer,replace=False)
except:
    print("😣😣😣😣Error😣😣😣😣")
    print(Answer)

# %%
rows = []
for q_key, q_value in Query_Response.items():
    question = q_value['Question']
    choices = q_value['Choice']
    
    row = {
        'Question': question,
        'Choice1': (choices['Choice1'][0], choices['Choice1'][1]),
        'Choice2': (choices['Choice2'][0], choices['Choice2'][1]),
        'Choice3': (choices['Choice3'][0], choices['Choice3'][1]),
        'Choice4': (choices['Choice4'][0], choices['Choice4'][1]),
    }
    rows.append(row)

df = pd.DataFrame(rows)
df
# Out:
#                                             Question  \
# 0  การสร้างเเชท GPT จำเป็นต้องมีความรู้ในด้านใดบ้าง?
# 1                             GPT ย่อมาจากคำว่าอะไร?
# 2  ในการสร้างเเชท GPT เราสามารถใช้โมเดล AI อะไรได...
# 3            เเชท GPT สามารถทำงานได้กับภาษาอะไรบ้าง?
# 4  ในการสร้างเเชท GPT เราจำเป็นต้องมีการฝึกฝนโมเด...
# 5                 เเชท GPT สามารถตอบคำถามได้อย่างไร?
# 6    เเชท GPT สามารถสร้างเนื้อหาขึ้นมาเองได้อย่างไร?
# 7   เเชท GPT สามารถทำงานร่วมกับระบบอื่นๆ ได้อย่างไร?
# 8      เเชท GPT สามารถปรับปรุงประสิทธิภาพได้อย่างไร?
# 9  เเชท GPT สามารถทำงานร่วมกับบริการ Cloud ได้อย่...
#
#                                              Choice1  \
# 0                                (ภาษา Python, 0.75)
# 1            (Generative Pre-trained Transformer, 1)
# 2                                        (BERT, 0.5)
# 3                                     (English, 0.5)
# 4                                (Fine-tuning, 0.75)
# 5           (โดยการใช้ข้อมูลที่ได้รับการฝึกฝน, 0.75)
# 6  (โดยการใช้เทคนิค Generative Adversarial Networ...
# 7                              (โดยการใช้ API, 0.75)
# 8           (โดยการใช้เทคนิค Ensemble Learning, 0.5)
# 9       (โดยการใช้บริการ Google Cloud Platform, 0.5)
#
#                                             Choice2  \
# 0                               (การเขียนโค้ด, 0.5)
# 1                         (General Purpose Text, 0)
# 2                                    (RoBERTa, 0.5)
# 3                                       (Thai, 0.5)
# 4                               (Pre-training, 0.5)
# 5               (โดยการใช้ AI ในการค้นหาคำตอบ, 0.5)
# 6                    (โดยการใช้เทคนิค Seq2Seq, 0.5)
# 7                          (โดยการใช้ Webhook, 0.5)
# 8            (โดยการใช้เทคนิค Active Learning, 0.5)
# 9  (โดยการใช้บริการ Amazon Web Services (AWS), 0.5)
#
#                                           Choice3  \
# 0                          (การทำงานกับ AI, 0.25)
# 1         (GPT: Generational Programming Tool, 0)
# 2                              (DistilBERT, 0.25)
# 3                                 (Chinese, 0.25)
# 4                       (Transfer Learning, 0.25)
# 5           (โดยการใช้โมเดลภาษาที่ถูกฝึกฝน, 0.25)
# 6  (โดยการใช้เทคนิค Reinforcement Learning, 0.25)
# 7                        (โดยการใช้ Socket, 0.25)
# 8       (โดยการใช้เทคนิค Transfer Learning, 0.25)
# 9         (โดยการใช้บริการ Microsoft Azure, 0.25)
#
#                                      Choice4
# 0                     (การออกแบบเว็บไซต์, 0)
# 1  (GPT: Graphical Programming Technique, 0)
# 2                                  (Siri, 0)
# 3                              (Japanese, 0)
# 4                   (Supervised Learning, 0)
# 5               (โดยการใช้ Google Search, 0)
# 6      (โดยการใช้เทคนิค Machine Learning, 0)
# 7                   (โดยการใช้ Bluetooth, 0)
# 8   (โดยการใช้เทคนิค Supervised Learning, 0)
# 9               (โดยการใช้บริการ Dropbox, 0)
