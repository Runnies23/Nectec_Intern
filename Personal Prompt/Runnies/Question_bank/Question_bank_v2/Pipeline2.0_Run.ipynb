# %%
import pandas as pd
import json
import os
import random
import requests

# %%
def QueryTyphoon_70b(Prompt,device='cuda',token=512,temp=0.3):
    endpoint = 'https://api.opentyphoon.ai/v1/chat/completions'
    res = requests.post(endpoint, json={
        "model": "typhoon-v1.5x-70b-instruct",
        "max_tokens": token,
        "messages":  [{"content": Prompt ,"role":"user"}],
        "temperature": temp,
        "top_p": 0.9,
        "top_k": 0,
        "repetition_penalty": 1.05,
        "min_p": 0
    }, headers={
        "Authorization": "Bearer sk-CuCbKpGo8mspCTGWEVkSXoDCTOt06BSnB5pH6RwxIZgeGCCm",
    })
    data = res.json()
    queries = data["choices"][0]["message"]["content"]
    # queries = queries.replace("%d.","")
    return queries

# %%
# concat.to_csv("Question_bank_v2.csv")
df_concept = pd.read_csv('Question_bank_v2.csv')
df_concept = df_concept.drop_duplicates(subset=['Question'],keep='first')
df_concept
# df = df.drop(['Unnamed: 0'],axis=1)
# df = df.rename(columns={'Unnamed: 0' : "Index"})
# df.to_csv("Question_bank_v2.csv",index=False)
# Out:
#      Index                                           Question         Level  \
# 0        0  ภาษา Python เป็นภาษาที่มีความสามารถในการทำงานไ...        Medium
# 1        1  คุณต้องการสร้างโปรแกรมนับจำนวนคำในไฟล์ข้อความ ...          Hard
# 2        2  การเขียนโปรแกรมภาษา Python สามารถทำได้หลายรูปแ...        Medium
# 3        3  ในภาษา Python มีการจัดการกับข้อมูลที่ไม่สมบูรณ...          Hard
# 4        4  การเขียนโปรแกรมภาษา Python จำเป็นต้องมีการระบุ...        Medium
# ..     ...                                                ...           ...
# 146    146  เมื่อเรียกฟังก์ชันและมีผิดพลาด (exception) เกิ...  Intermediate
# 147    147  ฟังก์ชันใดใน Python ที่สามารถใช้ร่วมกับ iterto...  Intermediate
# 148    148          ฟังก์ชันไหนบ้างที่สามารถใช้งานกับลิสต์ได้  Intermediate
# 149    149  คำสั่ง Python ใดที่ใช้เก็บข้อมูลในชุดข้อมูลที่...  Intermediate
# 150    150                วิธีการเขียนลูปใน Python มีอะไรบ้าง  Intermediate
#
#                                                 Choice
# 0    [{'text': 'การสร้างเกม', 'weight': 0.25}, {'te...
# 1    [{'text': 'ใช้ฟังก์ชัน read() ของโมดูล sys', '...
# 2    [{'text': 'การเขียนแบบ Interactive', 'weight':...
# 3    [{'text': 'โดยการใช้คำสั่ง try-except เพื่อจัด...
# 4    [{'text': 'ไม่จำเป็น', 'weight': 0.25}, {'text...
# ..                                                 ...
# 146  [{'text': 'return ค่าที่ไม่ถูกต้อง', 'weight':...
# 147  [{'text': 'zip()', 'weight': 0}, {'text': 'cha...
# 148  [{'text': 'sorted() และ reversed()', 'weight':...
# 149  [{'text': 'tuple', 'weight': 0.25}, {'text': '...
# 150  [{'text': 'for ลูปและ do-while ลูป', 'weight':...
#
# [151 rows x 4 columns]

# %%
# Question_bank_df =  pd.read_csv("../../../QuestionBank_VerySuperClean.csv")
Question_bank_df =  pd.read_csv("../v2/Concat_Question_Bank_Topic_V2_BIG_Clearning.csv")
# Question_bank_df.to_csv("../Question_bank_Topic_v2_1.csv")
# Question_bank_df = Question_bank_df.drop(['Unnamed: 0'],axis=1)
# Question_bank_df = Question_bank_df.rename(columns={'Unnamed: 0': "Index"})
# Question_bank_df.to_csv("../v2/Concat_Question_Bank_Topic_V2_BIG_Clearning.csv",index=False)
Question_bank_df
# Out:
#      Index                                           Question  \
# 0        0  การเขียนโปรแกรมภาษา Python จะใช้คำสั่ง if เพื่...
# 1        1  การเขียนโปรแกรมภาษา Python จะใช้คำสั่ง while เ...
# 2        2            คำสั่ง continue ใน Python ใช้เพื่ออะไร?
# 3        3                คำสั่ง elif ใน Python ใช้เพื่ออะไร?
# 4        4               คำสั่ง break ใน Python ใช้เพื่ออะไร?
# ..     ...                                                ...
# 278    278    ตัวอย่างของตัวแปรแบบจำนวนจริงใน Python คืออะไร?
# 279    279  การกำหนดค่าเริ่มต้นให้กับตัวแปรใน Python สามาร...
# 280    280  ตัวอย่างของค่าที่เป็นประเภทข้อมูล bool ในภาษา ...
# 281    281       ตัวแปรในภาษา Python สามารถเก็บค่าได้กี่ชนิด?
# 282    282  ในภาษา Python, การกำหนดค่าเริ่มต้นให้กับตัวแปร...
#
#                                                 Choice  \
# 0    [{'text': 'เพื่อสร้างฟังก์ชัน', 'weight': 0}, ...
# 1    [{'text': 'เพื่อตรวจสอบเงื่อนไข', 'weight': 0}...
# 2    [{'text': 'เพื่อยุติการทำงานของ loop', 'weight...
# 3    [{'text': 'เพื่อตรวจสอบเงื่อนไขหลัก', 'weight'...
# 4    [{'text': 'เพื่อยุติการทำงานของ loop', 'weight...
# ..                                                 ...
# 278  [{'text': '123', 'weight': 0}, {'text': "'Hell...
# 279  [{'text': '=', 'weight': 1}, {'text': '==', 'w...
# 280  [{'text': '123', 'weight': 0}, {'text': "'Hell...
# 281  [{'text': '2 ชนิด', 'weight': 0}, {'text': '3 ...
# 282  [{'text': 'การกำหนดค่าในทันที', 'weight': 1}, ...
#
#                        Topic   Level
# 0                ControlFlow    Easy
# 1                ControlFlow  Medium
# 2                ControlFlow  Medium
# 3                ControlFlow  Medium
# 4                ControlFlow  Medium
# ..                       ...     ...
# 278  Variables_and_DataTypes    Easy
# 279  Variables_and_DataTypes    Easy
# 280  Variables_and_DataTypes    Easy
# 281  Variables_and_DataTypes    Easy
# 282  Variables_and_DataTypes  Medium
#
# [283 rows x 5 columns]

# %% [markdown]
# #### RandoM

# %%
def Previous_Question(Response):
    Previous =[]
    for index, i in enumerate(Response):
        print()
        Previous.append(f"""{index+1}.\tQuestion : {i['Question']}\n\tTopic : {i['Topic']}\n\tLevel : {i['Level']}\n\tAnswer : {i['Answer']}\n\tBest Answer : {i['Best Answer']}\n\tPrevious Chain of Though : {i['Chain_of_Thought']}""")

    Previous_Text = '\n'.join(Previous)
    return Previous_Text

# %%
def Select_topic_and_level(Content,Level,DF=Question_bank_df):
    if Content and Level:
        Easy = [DF['Index'].iloc[i] for i in range(len(DF)) if DF['Level'].iloc[i] == Level and DF['Topic'].iloc[i] == Content]
        return Easy
    
def Question_bank_by_Index(Question_bank_index):
    Question_bank_Text  = []
    for index,i in enumerate(Question_bank_index):
        Question_bank_Text.append(f"Question : {Question_bank_df['Question'].iloc[i]}\nTopic : {Question_bank_df['Topic'].iloc[i]}\nLevel : {Question_bank_df['Level'].iloc[i]}")    

    Question_bank_Texts = '\n'.join(Question_bank_Text)
    return Question_bank_Texts

# %%
Question_bank_topic = Question_bank_df['Topic'].unique()
Question_bank_topic = ['\t- ' + i for i in Question_bank_topic]
Question_bank_topics = '\n'.join(Question_bank_topic)
print(Question_bank_topics)
# Out:
# 	- ControlFlow
# 	- Decorators and ContextManagers
# 	- Dictionaries
# 	- ErrorHandling
# 	- Functions
# 	- Imports
# 	- Input and Output
# 	- Iterators
# 	- List
# 	- Loops
# 	- Object-OrientedProgramming(OOP)
# 	- Set
# 	- Tuple
# 	- Variables_and_DataTypes

# %% [markdown]
# ### Prompt Function

# %%
def Prompt_Func(Question_bank_topics, Previous_Text):
    Prompt = f"""You are the **Greatest of All Time (GOAT)** in Python programming mentorship. Your role is to guide students through a learning journey that adapts to their strengths and weaknesses in Python concepts.

**Scenario**: 
- Your student is highly skilled, known as the **Best Python Programmer** for 5 years. Your job is to balance challenging them in areas they excel while providing support in areas where they struggle.

**Key Guidance for Crafting Questions**:

1. **Question Adaptation Strategy**:
    - Use **10 questions** to assess the student's knowledge, adapting questions based on their answers:
        - If the student answers a **medium question incorrectly**, provide an **easier question** to reinforce their understanding.
            - **Change the topic** to something less complex if they continue to struggle (e.g., from **OOP** to **functions**).
        - If the student answers the **easier question correctly**, move to a **slightly harder question** in the same topic or a topic that is more challenging (e.g., from **functions** to **OOP**).
        - If the student answers a **hard question correctly**, provide an even **more challenging question** or a **more complex topic** to push their limits (e.g., from **recursion** to **decorators**).
    - Adjust questions to ensure a balanced path:
        **Very Important Please follow strictly.**
        There are three levels of questions: Easy, Normal and Hard.      
        You will need to check that The answer that the user has given is How likely is it to be correct? If the answer is correct The next one will have a higher level of difficulty.
        *Example 1*
        [Question1]
        [Choice 1] (Answer Weight 0.5)
        [Choice 2] (Answer Weight 0.75)
        [Choice 3] (Answer Weight 1)
        [Choice 4] (Answer Weight 0)

        if user choose answer that weight 0.75 or 1 next *question must harder* like easy to normol or normal to hard.
        if user choose anster that weight 0.5  *don't change difficulty*.
        if user choose answer that weight 0.25 or 0 next *question must easier* like normal to easy or hard to normal.

    -Try to vary the content of your questions.
        **Very Important Please follow strictly.**
        We have a wide variety of questions for you to choose from. You'll want to make the content of your questions as diverse as possible.
        - You must change the question Topic every 1 - 2 questions.
        
2. **Available Data**:
    - You have access to 'Previous Questions' data, including:
        - 'question': The question text.
        - 'Topic': The topic covered.
        - 'Answer': The student's response have text and     weight.
        - 'Best Answer': The ideal answer contain text and choice weight.
        - 'Choice Weights': Indicates the correctness of each choice.
        - 'Previous Chain of Thought': The rationale behind previous question choices.
    - 'Question Bank Topics':
        {Question_bank_topics}

3. **Recommending the Next Question**:
    - Use **two modes** for selecting questions:
        - **Mode 1: Query from Question Bank**:
            - Select a question based on topic and difficulty (Easy, Medium, Hard).
            - Adjust the difficulty:
                - Move to **easier questions or topics** for incorrect answers.
                - Escalate to **harder questions or topics** for correct answers.
        - **Mode 2: Create a New Question**:
            - Use this mode for tailored questions when the student's needs are not met by existing questions.
            - Create a new question if a unique challenge is required to deepen understanding.

4. **Adjustments Based on Student's Performance**:
    - If the student struggles with a **medium question**, switch to an **easier question** or a **simpler topic**:
        - Example: If they struggle with a medium question on **OOP**, ask an **easy question** on **functions**.
    - If they succeed in an **easy question**, increase the difficulty level or switch to a **more complex topic**:
        - Example: If they do well on an easy question about **functions**, move to a **medium question** on **OOP**.
    - For correct answers to **hard questions**, challenge them further:
        - Example: If they answer a hard question on **recursion**, provide a **harder question** on **decorators**.
    - Include your reasoning in the 'Chain_of_Thought':
        - "The student struggled with a medium OOP question, so I selected an easy question on functions to reinforce basic concepts."
        - "After succeeding with an easy functions question, I chose a medium OOP question to push their knowledge further."
        - "They answered a hard recursion question correctly, so I moved to a harder decorators question to challenge them further."

5. **Priority**: All questions and answers must be in **Thai**, and your response should strictly follow the JSON format. No additional explanation is required.

Previous Questions:
{Previous_Text}
```
JSON Format for a Question from the Question Bank:
{{
    "Mode": 1,
    "Topic": "(topic)",
    "Level": "Easy" | "Medium" | "Hard",
    "Chain_of_Thought": "(Explain why this question was selected, how it escalates the challenge, and your reasoning for changing the topic or difficulty level. Focus on why an advanced topic was chosen if applicable)"
}}

JSON Format for Creating a New Question:
{{
    "Mode": 2,
    "Question": "(Question you create)",
    "Choices": [
        {{"text": "(Choice 1 in Thai)", "weight": (choice weight)}},
        {{"text": "(Choice 2 in Thai)", "weight": (choice weight)}},
        {{"text": "(Choice 3 in Thai)", "weight": (choice weight)}},
        {{"text": "(Choice 4 in Thai)", "weight": (choice weight)}}
    ],
    "Topic": "(topic)",
    "Level": "Easy" | "Medium" | "Hard",
    "Chain_of_Thought": "(Explain why this new question was created, how it will push the student further, and why the topic or difficulty was adjusted. Focus on the need to challenge them with harder problems when appropriate)"
}}
```"""
    return Prompt

# %%
def Prompt2_0_func(Previous_Question_History_Text):
    Prompt = f"""You are a Python professor tasked with assessing a student's knowledge based on their quiz history. Your goal is to determine their level using a maximum of **10** questions and ensure a comprehensive evaluation.

### Parameters to Follow:
1. **Question Limit**:
    - Use **10** questions or fewer.
    - Leverage existing quiz history to avoid redundancy and focus on knowledge gaps.
    - Use **Mode 2** if there are **fewer than 5 answers**, suggesting additional data may be needed.
    - Use **Mode 1** if there are **5 or more answers** to classify their knowledge level.

2. **Knowledge Levels**:
    - **Beginner1**: Newbie in Python.
    - **Beginner2**: Knows syntax and basic operations (e.g., `print`, `if-else`).
    - **Intermediate**: Understands basic concepts.
    - **Advanced1**: Understands OOP and error handling.
    - **Advanced2**: Python expert; can solve any quiz.
    - Assess based on quiz history and performance patterns (strong, mixed, weak).

### Evaluation Modes:
1. **Mode 1: Sufficient Data**:
    - Classify into **Beginner1**, **Beginner2**, **Intermediate**, **Advanced1**, or **Advanced2**.
    - Justify your classification with examples from their quiz answers.
    - Highlight key responses that indicate their understanding.

2. **Mode 2: Insufficient Data**:
    - Use when fewer than 5 questions are answered.
    - Identify strengths and areas needing more data.
    - Explain why current data isn't enough for a precise assessment.

3. **Decision Confidence**:
    - Provide clear reasoning in the 'Chain_of_Thought' for your decision.
    - Be cautious in borderline cases, using your expertise to guide recommendations.

**Priority**:
    - Strictly follow the specified JSON format without additional commentary.
    - No additional explanation is required.

Here is the JSON Format for Mode 1 (sufficient Data): 
{{  
    "Mode": 1,
    "Level": "Beginner1" | "Beginner2" | "Intermediate" | "Advanced1" | "Advanced2",
    "Chain_of_Thought": "(Explain why this level was determined based on previous performance, highlighting key answers and insights)"
}}  
Here is the JSON Format for Mode 2 (Insufficient Data):
{{  
    "Mode": 2,
    "Reason": "Not enough data to confidently determine the level.",
    "Chain_of_Thought": "(Explain why it's not possible to determine a precise level with the given history, and highlight areas of uncertainty)"
}}

Previous Questions:
{Previous_Question_History_Text}"""
    
    return Prompt

# %% [markdown]
# # Query 1

# %% [markdown]
# ## FIrst questipn

# %%
Response = []
Index_list = df_concept['Index']
Index_rand = random.choice(Index_list)
rows = df_concept.iloc[Index_rand]
print(f"Question : {rows['Question']}\n")
value = json.loads(rows['Choice'].replace("'",'"'))
weight = [i['weight'] for i in value]
for index, i in enumerate(value):
    print(f"{index+1}. {i['text']}")
print(weight)
decision = int(input()) -1 
Response.append({
    "Question" : rows['Question'],
    "Topic" : "Overview of Python",
    "Level" : "Medium",
    "Answer" : (weight[decision], value[decision]['text']),
    "Best Answer" : (weight[weight.index(max(weight))], value[weight.index(max(weight))]['text']),
    "Chain_of_Thought" : None
})
# Out:
# Question : การแก้ไขฟังก์ชันที่มีปัญหาเรื่อง edge case สามารถทำได้โดยการใช้:
#
# 1. Error handling ด้วย try-except
# 2. Unit testing
# 3. Type checking
# 4. Decorators
# [0, 1, 0.25, 0]

# %% [markdown]
# ## Loop

# %%
print(len(Response)+1)
# if Query2_json['Level'] and Query2_json['Topic']:
#     Query = QueryTyphoon_70b(Prompt_Func(Question_bank_topics,Previous_Question(Response)),token=512)
Query = QueryTyphoon_70b(Prompt_Func(Question_bank_topics,Previous_Question(Response)),token=512)
response = json.loads(Query)
response['Topic'] = response['Topic'].replace('OOP','Object-OrientedProgramming(OOP)')
print(response['Topic'],response['Level'])
if response['Mode'] == 1:
    if response['Topic'] == 'Overview of Python':
        Index = Select_topic_and_level(response['Topic'],response['Level'],DF=df_concept)
        Random_Choice_Index = random.choice(Index)
        rows = df_concept.iloc[Random_Choice_Index]
    else:
        Index = Select_topic_and_level(response['Topic'],response['Level'])
        Random_Choice_Index = random.choice(Index)
        rows = Question_bank_df.iloc[Random_Choice_Index]
    print(f"Question : {rows['Question']}\n")
    value = json.loads(rows['Choice'].replace("'",'"'))
    weight = [i['weight'] for i in value]
    for index, i in enumerate(value):
        print(f"{index+1}. {i['text']}")
    print(weight)
    decision = int(input()) -1 
    Response.append({
        "Question" : rows['Question'],
        "Topic" : rows['Topic'],
        "Level" : rows['Level'],
        "Answer" : (weight[decision], value[decision]['text']),
        "Best Answer" : (weight[weight.index(max(weight))], value[weight.index(max(weight))]['text']),
        "Chain_of_Thought" : response['Chain_of_Thought']
    })
    # print(Response)

if response['Mode'] == 2: 
    print(2)

# if Quer_2:
#    del Quer_2 

if len(Response)+1 > 10:
    Quer_2 = QueryTyphoon_70b(Prompt2_0_func(Previous_Question(Response)),token=512)
    Query2_json = json.loads(Quer_2)

    if Query2_json['Mode'] == 2:
        print("need more Question")
        print(Query2_json['Reason'])
        print(Query2_json['Chain_of_Thought'])
    else:
        print(f'Level : {Query2_json["Level"]}\nChain of though : {Query2_json["Chain_of_Thought"]}')
        Question_Knowledge_Level = Query2_json["Level"]
# Out:
# 10
#
#
#
#
#
#
#
#
#
# Object-OrientedProgramming(OOP) Medium
# Question : การกำหนดค่าเริ่มต้นให้กับ attribute ของคลาสในภาษา Python ทำได้โดยการใช้คำสั่งใด?
#
# 1. __init__
# 2. __str__
# 3. __repr__
# 4. __del__
# [1, 0, 0, 0]
#
#
#
#
#
#
#
#
#
#
# Level : Intermediate
# Chain of though : The student has demonstrated a consistent understanding of various Python concepts across multiple topics, including functions, error handling, iterators, lists, dictionaries, control flow, sets, decorators and context managers, and object-oriented programming. They have shown proficiency in answering medium-level questions correctly, indicating a solid grasp of the language. However, they have not yet demonstrated mastery of advanced concepts or the ability to solve hard-level questions consistently. Therefore, I have classified their knowledge level as 'Intermediate'. Key responses that indicate their understanding include their correct answers on function creation, error handling, iterator usage, list comprehension, and context manager implementation.

# %% [markdown]
# # Query 3

# %%
Prompt_Query3_not_enough_return_0 = f"""You are an AI expert in Python tasked with evaluating a student's knowledge based on their quiz history. Analyze their previous responses and determine their knowledge level for each topic.

### Parameters:
1. **Data Provided**:
   - 'Previous Questions' with the following details:
     - 'question': The text of the question.
     - 'topic': The subject area of the question.
     - 'answer': The student's response, including its weight.
     - 'best answer': The correct answer with its corresponding weight.
     - 'choice weights': Indicates the score for each choice.
     - 'previous chain of thought': The reasoning behind each of the student's choices.

2. **Knowledge Levels**:
   - **Beginner1**: Newbie in Python.
   - **Beginner2**: Knows syntax and basic operations (e.g., `print`, `if-else`).
   - **Intermediate**: Understands basic concepts.
   - **Advanced1**: Understands OOP and error handling.
   - **Advanced2**: Python expert; can solve any quiz.
   - Assess the student's level based on quiz history and performance patterns (strong, mixed, weak).


Python Knowledge Assessment Criteria:

all wrong answer or answer incorrectly style:
You are unfamiliar with Python, have not encountered it before, but are eager to learn.

reach 2/10 up:
You have a basic awareness of Python (about 10% knowledge), but your understanding is minimal. You know what Python is but haven't delved deeply into any topic.

reach 4/10 up:
You grasp the basic concepts of Python and can understand some functions. You're aware of how things work but need more practice. You also want a structured plan to dive deeper into the topics.

reach 6/10 up:
You have a solid understanding of Python (about 50% knowledge). You can explain, read, and write basic code confidently. You're looking for a learning plan to improve your skills further and cover more advanced topics.

reach 8/10 up:
You possess an advanced understanding of Python (between 50% and 80%). You can explain, read, understand, and adapt code to new problems. You understand mathematical concepts related to Python, or you're a senior-level developer looking for a refresher on specific areas.

reach 9/10 up:
You have mastered Python (over 80% knowledge). You can do everything listed above and need only occasional revision to stay sharp on particular topics.

IMPORTANT!! :
**keep data as round by round because the correct answer can have different score but them =! 0 absolutely**
**output become class and persentage in each of topics**

### Chain of Thought:
- Explain uncertainties in knowledge assessment based on the student's history and highlight areas that lack sufficient data.
   
### Output Requirement:
- Return the results strictly in JSON format, without any additional explanation, using the structure below:
```json
[
    {{
        "Topic": "Topic1",
        "Knowledge_Level": Level
        "Chain_of_Thought": "(Explain why it's not possible to determine a precise level with the given history, and highlight areas of uncertainty)"
    }},
    {{
        "Topic": "Topic2",
        "Knowledge_Level": Level
        "Chain_of_Thought": "(Explain why it's not possible to determine a precise level with the given history, and highlight areas of uncertainty)"
    }}
]



Topics to Evaluate:
{Question_bank_topics}

Student level Knowledge 
{Question_Knowledge_Level}

Student's Quiz History:
{Previous_Question(Response)}
"""
print(Prompt_Query3_not_enough_return_0)
# Out:
# You are an AI expert in Python tasked with evaluating a student's knowledge based on their quiz history. Analyze their previous responses and determine their knowledge level for each topic.
#
# ### Parameters:
# 1. **Data Provided**:
#    - 'Previous Questions' with the following details:
#      - 'question': The text of the question.
#      - 'topic': The subject area of the question.
#      - 'answer': The student's response, including its weight.
#      - 'best answer': The correct answer with its corresponding weight.
#      - 'choice weights': Indicates the score for each choice.
#      - 'previous chain of thought': The reasoning behind each of the student's choices.
#
# 2. **Knowledge Levels**:
#    - **Beginner1**: Newbie in Python.
#    - **Beginner2**: Knows syntax and basic operations (e.g., `print`, `if-else`).
#    - **Intermediate**: Understands basic concepts.
#    - **Advanced1**: Understands OOP and error handling.
#    - **Advanced2**: Python expert; can solve any quiz.
#    - Assess the student's level based on quiz history and performance patterns (strong, mixed, weak).
#
#
# Python Knowledge Assessment Criteria:
#
# all wrong answer or answer incorrectly style:
# You are unfamiliar with Python, have not encountered it before, but are eager to learn.
#
# reach 2/10 up:
# You have a basic awareness of Python (about 10% knowledge), but your understanding is minimal. You know what Python is but haven't delved deeply into any topic.
#
# reach 4/10 up:
# You grasp the basic concepts of Python and can understand some functions. You're aware of how things work but need more practice. You also want a structured plan to dive deeper into the topics.
#
# reach 6/10 up:
# You have a solid understanding of Python (about 50% knowledge). You can explain, read, and write basic code confidently. You're looking for a learning plan to improve your skills further and cover more advanced topics.
#
# reach 8/10 up:
# You possess an advanced understanding of Python (between 50% and 80%). You can explain, read, understand, and adapt code to new problems. You understand mathematical concepts related to Python, or you're a senior-level developer looking for a refresher on specific areas.
#
# reach 9/10 up:
# You have mastered Python (over 80% knowledge). You can do everything listed above and need only occasional revision to stay sharp on particular topics.
#
# IMPORTANT!! :
# **keep data as round by round because the correct answer can have different score but them =! 0 absolutely**
# **output become class and persentage in each of topics**
#
# ### Chain of Thought:
# - Explain uncertainties in knowledge assessment based on the student's history and highlight areas that lack sufficient data.
#
# ### Output Requirement:
# - Return the results strictly in JSON format, without any additional explanation, using the structure below:
# ```json
# [
#     {
#         "Topic": "Topic1",
#         "Knowledge_Level": Level
#         "Chain_of_Thought": "(Explain why it's not possible to determine a precise level with the given history, and highlight areas of uncertainty)"
#     },
#     {
#         "Topic": "Topic2",
#         "Knowledge_Level": Level
#         "Chain_of_Thought": "(Explain why it's not possible to determine a precise level with the given history, and highlight areas of uncertainty)"
#     }
# ]
#
#
#
# Topics to Evaluate:
# 	- ControlFlow
# 	- Decorators and ContextManagers
# 	- Dictionaries
# 	- ErrorHandling
# 	- Functions
# 	- Imports
# 	- Input and Output
# 	- Iterators
# 	- List
# 	- Loops
# 	- Object-OrientedProgramming(OOP)
# 	- Set
# 	- Tuple
# 	- Variables_and_DataTypes
#
# Student level Knowledge
# Intermediate
#
# Student's Quiz History:
# 1.	Question : การแก้ไขฟังก์ชันที่มีปัญหาเรื่อง edge case สามารถทำได้โดยการใช้:
# 	Topic : Overview of Python
# 	Level : Medium
# 	Answer : (1, 'Unit testing')
# 	Best Answer : (1, 'Unit testing')
# 	Previous Chain of Though : None
# 2.	Question : การสร้างฟังก์ชันใน Python จะต้องมีคำสั่งใด?
# 	Topic : Functions
# 	Level : Medium
# 	Answer : (1, 'def')
# 	Best Answer : (1, 'def')
# 	Previous Chain of Though : The student has shown proficiency in various Python concepts. To challenge them further, I selected a medium-level question on functions, which is a fundamental yet complex topic. This question will test their understanding of function arguments and return values.
# 3.	Question : คำสั่ง else ใน block try-except ใช้สำหรับอะไร?
# 	Topic : ErrorHandling
# 	Level : Medium
# 	Answer : (1, 'ประมวลผลโค้ดเมื่อไม่เกิด Error')
# 	Best Answer : (1, 'ประมวลผลโค้ดเมื่อไม่เกิด Error')
# 	Previous Chain of Though : The student has demonstrated strong knowledge in various Python concepts. To continue challenging them, I selected a medium-level question on error handling, which is an essential topic for any advanced Python programmer. This question will test their understanding of exception handling and how to use try-except blocks effectively.
# 4.	Question : เมื่อเรียกใช้ฟังก์ชัน next() บนอ็อบเจ็กต์ iterator จะเกิดอะไรขึ้น?
# 	Topic : Iterators
# 	Level : Medium
# 	Answer : (1, 'จะแสดงค่าถัดไป')
# 	Best Answer : (1, 'จะแสดงค่าถัดไป')
# 	Previous Chain of Though : The student has shown proficiency in various Python concepts. To challenge them further, I selected a medium-level question on iterators, which is an advanced topic that requires a deep understanding of Python's internal workings. This question will test their knowledge of how iterators work and how to use them effectively.
# 5.	Question : list comprehension สามารถใช้เงื่อนไข if เพิ่มเติมได้หรือไม่
# 	Topic : List
# 	Level : Medium
# 	Answer : (1, 'สามารถ')
# 	Best Answer : (1, 'สามารถ')
# 	Previous Chain of Though : The student has shown proficiency in various Python concepts. To challenge them further, I selected a medium-level question on lists, which is a fundamental yet complex topic. This question will test their understanding of list manipulation and indexing.
# 6.	Question : การใช้งาน Decorator มีข้อดีอย่างไร?
# 	Topic : Dictionaries
# 	Level : Medium
# 	Answer : (1, 'ช่วยให้โค้ดมีความกระชับและอ่านง่าย')
# 	Best Answer : (1, 'ช่วยให้โค้ดมีความกระชับและอ่านง่าย')
# 	Previous Chain of Though : The student has demonstrated strong knowledge in various Python concepts. To continue challenging them, I selected a medium-level question on dictionaries, which is an essential topic for any advanced Python programmer. This question will test their understanding of dictionary manipulation and methods.
# 7.	Question : การใช้คำสั่ง while ในภาษา Python ใช้สำหรับอะไร?
# 	Topic : ControlFlow
# 	Level : Medium
# 	Answer : (1, 'การวนลูป')
# 	Best Answer : (1, 'การวนลูป')
# 	Previous Chain of Though : The student has demonstrated strong knowledge in various Python concepts. To continue challenging them, I selected a medium-level question on control flow, which is an essential topic for any advanced Python programmer. This question will test their understanding of conditional statements and loop structures.
# 8.	Question : การรวมเซตในภาษาไพธอนสามารถทำได้โดยการใช้คำสั่งอะไร?
# 	Topic : Set
# 	Level : Medium
# 	Answer : (1, 'union()')
# 	Best Answer : (1, 'union()')
# 	Previous Chain of Though : The student has demonstrated strong knowledge in various Python concepts. To continue challenging them, I selected a medium-level question on sets, which is an essential topic for any advanced Python programmer. This question will test their understanding of set operations and properties.
# 9.	Question : การทำงานของ Context Manager มีขั้นตอนใดบ้าง?
# 	Topic : Decorators and ContextManagers
# 	Level : Hard
# 	Answer : (1, '__enter__ และ __exit__')
# 	Best Answer : (1, '__enter__ และ __exit__')
# 	Previous Chain of Though : The student has consistently demonstrated strong knowledge in various Python concepts. To challenge them further, I selected a hard-level question on decorators and context managers, which is an advanced topic that requires a deep understanding of Python's internals. This question will test their ability to apply decorators to modify function behavior and manage resources using context managers.
# 10.	Question : การกำหนดค่าเริ่มต้นให้กับ attribute ของคลาสในภาษา Python ทำได้โดยการใช้คำสั่งใด?
# 	Topic : Object-OrientedProgramming(OOP)
# 	Level : Medium
# 	Answer : (1, '__init__')
# 	Best Answer : (1, '__init__')
# 	Previous Chain of Though : The student has demonstrated strong knowledge in various Python concepts. To continue challenging them, I selected a medium-level question on Object-Oriented Programming (OOP), which is an essential topic for any advanced Python programmer. This question will test their understanding of classes, inheritance, and polymorphism.

# %%
Prompt_Query3_approximate = f"""You are an AI expert in Python tasked with evaluating a student's knowledge based on their quiz history and recent progress. Analyze their responses and determine their knowledge level for each topic, as well as an overall assessment level.

### Parameters:
1. **Data Provided**:
   - 'Previous Questions' with the following details:
     - 'question': The text of the question.
     - 'topic': The subject area of the question.
     - 'answer': The student's response, including its weight.
     - 'best answer': The correct answer with its corresponding weight.
     - 'choice weights': Indicates the score for each choice.
     - 'previous chain of thought': The reasoning behind each of the student's choices.
     - Knowledge Levels
            - **Beginner1**: Newbie in Python.
            - **Beginner2**: Knows syntax and basic operations (e.g., `print`, `if-else`).
            - **Intermediate**: Understands basic concepts.
            - **Advanced1**: Understands OOP and error handling.
            - **Advanced2**: Python expert; can solve any quiz.
            - Assess the student's level based on quiz history and performance patterns (strong, mixed, weak).

2. **Knowledge Assessment**:
   - Calculate a 'Knowledge_Level' for each topic ranging from 1 to 5, where 1 indicates minimal knowledge and 5 indicates mastery.
   - If there is insufficient data for a topic, approximate the knowledge level based on similar topics or general trends in the student's performance.
   - Additionally, provide the student's overall level using the above categories.

Python Knowledge Assessment Criteria:

all wrong answer or answer incorrectly style:
You are unfamiliar with Python, have not encountered it before, but are eager to learn.

reach 2/10 up:
You have a basic awareness of Python (about 10% knowledge), but your understanding is minimal. You know what Python is but haven't delved deeply into any topic.

reach 4/10 up:
You grasp the basic concepts of Python and can understand some functions. You're aware of how things work but need more practice. You also want a structured plan to dive deeper into the topics.

reach 6/10 up:
You have a solid understanding of Python (about 50% knowledge). You can explain, read, and write basic code confidently. You're looking for a learning plan to improve your skills further and cover more advanced topics.

reach 8/10 up:
You possess an advanced understanding of Python (between 50% and 80%). You can explain, read, understand, and adapt code to new problems. You understand mathematical concepts related to Python, or you're a senior-level developer looking for a refresher on specific areas.

reach 9/10 up:
You have mastered Python (over 80% knowledge). You can do everything listed above and need only occasional revision to stay sharp on particular topics.

IMPORTANT!! :
**keep data as round by round because the correct answer can have different score but them =! 0 absolutely**
**output become class and persentage in each of topics**

### Output Requirement:
- Return the results strictly in JSON format, without any additional explanation, using the structure below:
```json
[
    {{
        "Topic": "Topic1",
        "Knowledge_Level": Level
    }},
    {{
        "Topic": "Topic2",
        "Knowledge_Level": Level
    }}
]


```
Topics to Evaluate:
{Question_bank_topics}

Student's Quiz History:
{Previous_Question(Response)} 
"""
print(Prompt_Query3_approximate)
# Out:
# You are an AI expert in Python tasked with evaluating a student's knowledge based on their quiz history and recent progress. Analyze their responses and determine their knowledge level for each topic, as well as an overall assessment level.
#
# ### Parameters:
# 1. **Data Provided**:
#    - 'Previous Questions' with the following details:
#      - 'question': The text of the question.
#      - 'topic': The subject area of the question.
#      - 'answer': The student's response, including its weight.
#      - 'best answer': The correct answer with its corresponding weight.
#      - 'choice weights': Indicates the score for each choice.
#      - 'previous chain of thought': The reasoning behind each of the student's choices.
#      - Knowledge Levels
#             - **Beginner1**: Newbie in Python.
#             - **Beginner2**: Knows syntax and basic operations (e.g., `print`, `if-else`).
#             - **Intermediate**: Understands basic concepts.
#             - **Advanced1**: Understands OOP and error handling.
#             - **Advanced2**: Python expert; can solve any quiz.
#             - Assess the student's level based on quiz history and performance patterns (strong, mixed, weak).
#
# 2. **Knowledge Assessment**:
#    - Calculate a 'Knowledge_Level' for each topic ranging from 1 to 5, where 1 indicates minimal knowledge and 5 indicates mastery.
#    - If there is insufficient data for a topic, approximate the knowledge level based on similar topics or general trends in the student's performance.
#    - Additionally, provide the student's overall level using the above categories.
#
# Python Knowledge Assessment Criteria:
#
# all wrong answer or answer incorrectly style:
# You are unfamiliar with Python, have not encountered it before, but are eager to learn.
#
# reach 2/10 up:
# You have a basic awareness of Python (about 10% knowledge), but your understanding is minimal. You know what Python is but haven't delved deeply into any topic.
#
# reach 4/10 up:
# You grasp the basic concepts of Python and can understand some functions. You're aware of how things work but need more practice. You also want a structured plan to dive deeper into the topics.
#
# reach 6/10 up:
# You have a solid understanding of Python (about 50% knowledge). You can explain, read, and write basic code confidently. You're looking for a learning plan to improve your skills further and cover more advanced topics.
#
# reach 8/10 up:
# You possess an advanced understanding of Python (between 50% and 80%). You can explain, read, understand, and adapt code to new problems. You understand mathematical concepts related to Python, or you're a senior-level developer looking for a refresher on specific areas.
#
# reach 9/10 up:
# You have mastered Python (over 80% knowledge). You can do everything listed above and need only occasional revision to stay sharp on particular topics.
#
# IMPORTANT!! :
# **keep data as round by round because the correct answer can have different score but them =! 0 absolutely**
# **output become class and persentage in each of topics**
#
# ### Output Requirement:
# - Return the results strictly in JSON format, without any additional explanation, using the structure below:
# ```json
# [
#     {
#         "Topic": "Topic1",
#         "Knowledge_Level": Level
#     },
#     {
#         "Topic": "Topic2",
#         "Knowledge_Level": Level
#     }
# ]
#
#
# ```
# Topics to Evaluate:
# 	- ControlFlow
# 	- Decorators and ContextManagers
# 	- Dictionaries
# 	- ErrorHandling
# 	- Functions
# 	- Imports
# 	- Input and Output
# 	- Iterators
# 	- List
# 	- Loops
# 	- Object-OrientedProgramming(OOP)
# 	- Set
# 	- Tuple
# 	- Variables_and_DataTypes
#
# Student's Quiz History:
# 1.	Question : การแก้ไขฟังก์ชันที่มีปัญหาเรื่อง edge case สามารถทำได้โดยการใช้:
# 	Topic : Overview of Python
# 	Level : Medium
# 	Answer : (1, 'Unit testing')
# 	Best Answer : (1, 'Unit testing')
# 	Previous Chain of Though : None
# 2.	Question : การสร้างฟังก์ชันใน Python จะต้องมีคำสั่งใด?
# 	Topic : Functions
# 	Level : Medium
# 	Answer : (1, 'def')
# 	Best Answer : (1, 'def')
# 	Previous Chain of Though : The student has shown proficiency in various Python concepts. To challenge them further, I selected a medium-level question on functions, which is a fundamental yet complex topic. This question will test their understanding of function arguments and return values.
# 3.	Question : คำสั่ง else ใน block try-except ใช้สำหรับอะไร?
# 	Topic : ErrorHandling
# 	Level : Medium
# 	Answer : (1, 'ประมวลผลโค้ดเมื่อไม่เกิด Error')
# 	Best Answer : (1, 'ประมวลผลโค้ดเมื่อไม่เกิด Error')
# 	Previous Chain of Though : The student has demonstrated strong knowledge in various Python concepts. To continue challenging them, I selected a medium-level question on error handling, which is an essential topic for any advanced Python programmer. This question will test their understanding of exception handling and how to use try-except blocks effectively.
# 4.	Question : เมื่อเรียกใช้ฟังก์ชัน next() บนอ็อบเจ็กต์ iterator จะเกิดอะไรขึ้น?
# 	Topic : Iterators
# 	Level : Medium
# 	Answer : (1, 'จะแสดงค่าถัดไป')
# 	Best Answer : (1, 'จะแสดงค่าถัดไป')
# 	Previous Chain of Though : The student has shown proficiency in various Python concepts. To challenge them further, I selected a medium-level question on iterators, which is an advanced topic that requires a deep understanding of Python's internal workings. This question will test their knowledge of how iterators work and how to use them effectively.
# 5.	Question : list comprehension สามารถใช้เงื่อนไข if เพิ่มเติมได้หรือไม่
# 	Topic : List
# 	Level : Medium
# 	Answer : (1, 'สามารถ')
# 	Best Answer : (1, 'สามารถ')
# 	Previous Chain of Though : The student has shown proficiency in various Python concepts. To challenge them further, I selected a medium-level question on lists, which is a fundamental yet complex topic. This question will test their understanding of list manipulation and indexing.
# 6.	Question : การใช้งาน Decorator มีข้อดีอย่างไร?
# 	Topic : Dictionaries
# 	Level : Medium
# 	Answer : (1, 'ช่วยให้โค้ดมีความกระชับและอ่านง่าย')
# 	Best Answer : (1, 'ช่วยให้โค้ดมีความกระชับและอ่านง่าย')
# 	Previous Chain of Though : The student has demonstrated strong knowledge in various Python concepts. To continue challenging them, I selected a medium-level question on dictionaries, which is an essential topic for any advanced Python programmer. This question will test their understanding of dictionary manipulation and methods.
# 7.	Question : การใช้คำสั่ง while ในภาษา Python ใช้สำหรับอะไร?
# 	Topic : ControlFlow
# 	Level : Medium
# 	Answer : (1, 'การวนลูป')
# 	Best Answer : (1, 'การวนลูป')
# 	Previous Chain of Though : The student has demonstrated strong knowledge in various Python concepts. To continue challenging them, I selected a medium-level question on control flow, which is an essential topic for any advanced Python programmer. This question will test their understanding of conditional statements and loop structures.
# 8.	Question : การรวมเซตในภาษาไพธอนสามารถทำได้โดยการใช้คำสั่งอะไร?
# 	Topic : Set
# 	Level : Medium
# 	Answer : (1, 'union()')
# 	Best Answer : (1, 'union()')
# 	Previous Chain of Though : The student has demonstrated strong knowledge in various Python concepts. To continue challenging them, I selected a medium-level question on sets, which is an essential topic for any advanced Python programmer. This question will test their understanding of set operations and properties.
# 9.	Question : การทำงานของ Context Manager มีขั้นตอนใดบ้าง?
# 	Topic : Decorators and ContextManagers
# 	Level : Hard
# 	Answer : (1, '__enter__ และ __exit__')
# 	Best Answer : (1, '__enter__ และ __exit__')
# 	Previous Chain of Though : The student has consistently demonstrated strong knowledge in various Python concepts. To challenge them further, I selected a hard-level question on decorators and context managers, which is an advanced topic that requires a deep understanding of Python's internals. This question will test their ability to apply decorators to modify function behavior and manage resources using context managers.
# 10.	Question : การกำหนดค่าเริ่มต้นให้กับ attribute ของคลาสในภาษา Python ทำได้โดยการใช้คำสั่งใด?
# 	Topic : Object-OrientedProgramming(OOP)
# 	Level : Medium
# 	Answer : (1, '__init__')
# 	Best Answer : (1, '__init__')
# 	Previous Chain of Though : The student has demonstrated strong knowledge in various Python concepts. To continue challenging them, I selected a medium-level question on Object-Oriented Programming (OOP), which is an essential topic for any advanced Python programmer. This question will test their understanding of classes, inheritance, and polymorphism.

# %%
print(f"Student Level : {Question_Knowledge_Level}")

Query3 = QueryTyphoon_70b(Prompt_Query3_not_enough_return_0,token=1024)
Query3_json = json.loads(Query3)
for i in Query3_json:
    print(f"Topic : {i['Topic'].ljust(30)}\t\t{i['Knowledge_Level']}")
# Out:
# Student Level : Intermediate
# Topic : ControlFlow                   		Intermediate
# Topic : Decorators and ContextManagers		Intermediate
# Topic : Dictionaries                  		Intermediate
# Topic : ErrorHandling                 		Intermediate
# Topic : Functions                     		Intermediate
# Topic : Imports                       		Unknown
# Topic : Input and Output              		Unknown
# Topic : Iterators                     		Intermediate
# Topic : List                          		Intermediate
# Topic : Loops                         		Unknown
# Topic : Object-OrientedProgramming(OOP)		Intermediate
# Topic : Set                           		Intermediate
# Topic : Tuple                         		Unknown
# Topic : Variables_and_DataTypes       		Unknown

# %%
Prompt_sum  ="""
You are the planner for guide student and you see the student level and score then you want to tell them what they can and cant do,


"""
\t{i['Persentage']}
# Out:
#   Cell In[159], line 6
#     \t{i['Persentage']}
#      ^
# SyntaxError: unexpected character after line continuation character
