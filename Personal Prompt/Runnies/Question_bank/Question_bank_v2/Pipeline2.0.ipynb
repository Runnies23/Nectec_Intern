# %%
import pandas as pd
import json
import os
import random
import requests

# %%
def QueryTyphoon_70b(Prompt,device='cuda',token=512,temp=0.3):
    endpoint = 'https://api.opentyphoon.ai/v1/chat/completions'
    res = requests.post(endpoint, json={
        "model": "typhoon-v1.5x-70b-instruct",
        "max_tokens": token,
        "messages":  [{"content": Prompt ,"role":"user"}],
        "temperature": temp,
        "top_p": 0.9,
        "top_k": 0,
        "repetition_penalty": 1.05,
        "min_p": 0
    }, headers={
        "Authorization": "Bearer sk-CuCbKpGo8mspCTGWEVkSXoDCTOt06BSnB5pH6RwxIZgeGCCm",
    })
    data = res.json()
    queries = data["choices"][0]["message"]["content"]
    # queries = queries.replace("%d.","")
    return queries

# %%
os.listdir('./')
# Out:
# ['Clean.ipynb', 'Question_bank_v2_kwan.csv', 'Question_bank_v2_run.csv']

# %%
# df1 = pd.read_csv("Question_bank_v2_kwan.csv")
# df2 = pd.read_csv("Question_bank_v2_run.csv")
# concat = pd.concat([df1,df2])
# concat

# %%
# concat.to_csv("Question_bank_v2.csv")
df = pd.read_csv('Question_bank_v2.csv')
df = df.drop_duplicates(subset=['Question'],keep='first')
df
# df = df.drop(['Unnamed: 0'],axis=1)
# df = df.rename(columns={'Unnamed: 0' : "Index"})
# df.to_csv("Question_bank_v2.csv",index=False)
# Out:
#      Index                                           Question         Level  \
# 0        0  ภาษา Python เป็นภาษาที่มีความสามารถในการทำงานไ...        Medium
# 1        1  คุณต้องการสร้างโปรแกรมนับจำนวนคำในไฟล์ข้อความ ...          Hard
# 2        2  การเขียนโปรแกรมภาษา Python สามารถทำได้หลายรูปแ...        Medium
# 3        3  ในภาษา Python มีการจัดการกับข้อมูลที่ไม่สมบูรณ...          Hard
# 4        4  การเขียนโปรแกรมภาษา Python จำเป็นต้องมีการระบุ...        Medium
# ..     ...                                                ...           ...
# 146    146  เมื่อเรียกฟังก์ชันและมีผิดพลาด (exception) เกิ...  Intermediate
# 147    147  ฟังก์ชันใดใน Python ที่สามารถใช้ร่วมกับ iterto...  Intermediate
# 148    148          ฟังก์ชันไหนบ้างที่สามารถใช้งานกับลิสต์ได้  Intermediate
# 149    149  คำสั่ง Python ใดที่ใช้เก็บข้อมูลในชุดข้อมูลที่...  Intermediate
# 150    150                วิธีการเขียนลูปใน Python มีอะไรบ้าง  Intermediate
#
#                                                 Choice
# ...

# %%
# Question_bank_df =  pd.read_csv("../../../QuestionBank_VerySuperClean.csv")
Question_bank_df =  pd.read_csv("../v2/Concat_Question_Bank_Topic_V2_BIG_Clearning.csv")
# Question_bank_df.to_csv("../Question_bank_Topic_v2_1.csv")
# Question_bank_df = Question_bank_df.drop(['Unnamed: 0'],axis=1)
# Question_bank_df = Question_bank_df.rename(columns={'Unnamed: 0': "Index"})
# Question_bank_df.to_csv("../v2/Concat_Question_Bank_Topic_V2_BIG_Clearning.csv",index=False)
Question_bank_df
# Out:
#      Index                                           Question  \
# 0        0  การเขียนโปรแกรมภาษา Python จะใช้คำสั่ง if เพื่...
# 1        1  การเขียนโปรแกรมภาษา Python จะใช้คำสั่ง while เ...
# 2        2            คำสั่ง continue ใน Python ใช้เพื่ออะไร?
# 3        3                คำสั่ง elif ใน Python ใช้เพื่ออะไร?
# 4        4               คำสั่ง break ใน Python ใช้เพื่ออะไร?
# ..     ...                                                ...
# 278    278    ตัวอย่างของตัวแปรแบบจำนวนจริงใน Python คืออะไร?
# 279    279  การกำหนดค่าเริ่มต้นให้กับตัวแปรใน Python สามาร...
# 280    280  ตัวอย่างของค่าที่เป็นประเภทข้อมูล bool ในภาษา ...
# 281    281       ตัวแปรในภาษา Python สามารถเก็บค่าได้กี่ชนิด?
# 282    282  ในภาษา Python, การกำหนดค่าเริ่มต้นให้กับตัวแปร...
#
#                                                 Choice  \
# 0    [{'text': 'เพื่อสร้างฟังก์ชัน', 'weight': 0}, ...
# 1    [{'text': 'เพื่อตรวจสอบเงื่อนไข', 'weight': 0}...
# ...

# %% [markdown]
# #### RandoM

# %%
def Previous_Question(Response):
    Previous =[]
    for index, i in enumerate(Response):
        print()
        Previous.append(f"""{index+1}.\tQuestion : {i['Question']}\n\tTopic : {i['Topic']}\n\tAnswer : {i['Answer']}\n\tBest Answer : {i['Best Answer']}""")

    Previous_Text = '\n'.join(Previous)
    return Previous_Text

# %%
def Select_topic_and_level(Content,Level):
    if Content and Level:
        Easy = [Question_bank_df['Index'].iloc[i] for i in range(len(Question_bank_df)) if Question_bank_df['Level'].iloc[i] == Level and Question_bank_df['Topic'].iloc[i] == Content]
        return Easy
    
def Question_bank_by_Index(Question_bank_index):
    Question_bank_Text  = []
    for index,i in enumerate(Question_bank_index):
        Question_bank_Text.append(f"Question : {Question_bank_df['Question'].iloc[i]}\nTopic : {Question_bank_df['Topic'].iloc[i]}\nLevel : {Question_bank_df['Level'].iloc[i]}")    

    Question_bank_Texts = '\n'.join(Question_bank_Text)
    return Question_bank_Texts

# %%
Question_bank_topic = Question_bank_df['Topic'].unique()
Question_bank_topic = ['\t- ' + i for i in Question_bank_topic]
Question_bank_topics = '\n'.join(Question_bank_topic)
print(Question_bank_topics)
# Out:
# 	- ControlFlow
# 	- Decorators and ContextManagers
# 	- Dictionaries
# 	- ErrorHandling
# 	- Functions
# 	- Imports
# 	- Input and Output
# 	- Iterators
# 	- List
# 	- Loops
# 	- Object-OrientedProgramming(OOP)
# 	- Set
# 	- Tuple
# 	- Variables_and_DataTypes

# %%
Response = []
Index_list = df['Index']
Index_rand = random.choice(Index_list)
rows = df.iloc[Index_rand]
print(f"Question : {rows['Question']}\n")
value = json.loads(rows['Choice'].replace("'",'"'))
weight = [i['weight'] for i in value]
for index, i in enumerate(value):
    print(f"{index+1}. {i['text']}")
print(weight)
decision = int(input()) -1 
Response.append({
    "Question" : rows['Question'],
    "Topic" : "Overview of Python",
    "Answer" : (weight[decision], value[decision]['text']),
    "Best Answer" : (weight[weight.index(max(weight))], value[weight.index(max(weight))]['text'])
})
Response
# Out:
# Question : ฟังก์ชันใดใน Python ที่ใช้สำหรับการเรียงลำดับข้อมูล
#
# 1. sorted()
# 2. reverse()
# 3. shuffle()
# 4. min()
# [1, 0, 0, 0]
# [{'Question': 'ฟังก์ชันใดใน Python ที่ใช้สำหรับการเรียงลำดับข้อมูล',
#   'Topic': 'Overview of Python',
#   'Answer': (1, 'sorted()'),
#   'Best Answer': (1, 'sorted()')}]

# %%
Prompt = f"""
You are a professor specializing in Python. Your task is to recommend the next question to measure a student's knowledge of Python topics. The goal is to use as few questions as possible while ensuring a comprehensive and efficient evaluation of the student's understanding.

Please follow the rules below when recommending the next question. All responses should be in the JSON format provided:

1. You have data to help you make a decision. The data includes the 'Previous Questions', each containing:
   - 'question': The text of the question.
   - 'Answer': The student's selected answer.
   - 'Best Answer': The choice with the highest score or the most accurate answer.
   - Each question has 4 choices, each with a personal score.
2. When recommending the next question, consider these factors:
   - **Topic Selection**: Analyze the student's previous answers to decide the next topic. For example:
     - The Answer have 3 mode first is Question Bank that mean next question ill query to question bank to get the question and Second is Create a new question and Third one is return when ensure the student knowledge level
     - If the student answers questions about functions accurately, move to a more difficult question in the same topic or advance to a harder concept like Object-Oriented Programming (OOP).
     - If a student's understanding seems dynamic, consider creating a new question that challenges their flexibility in Python.
   - **Performance Analysis**: Evaluate the student's performance in previous questions:
     - If the student consistently selects the 'Best Answer' or has high scores, recommend a more challenging question to verify their deep understanding of the topic.
     - If the difference between the chosen answer and the 'Best Answer' is small, the student may need a follow-up question in the same topic to confirm their grasp of the material.
     - If the student's answers seem to reflect guessing rather than confident knowledge, provide a simpler question in a new topic or a different angle within the same topic to ensure understanding.
3. **Mode 3 Condition**: If the data from the student's previous answers is sufficient to confidently assess their level, return "Mode 3" along with the student's level ('Beginner', 'Intermediate', or 'Advanced'). 
   - Use this mode only when you are certain that the student's performance in the previous questions provides a clear indication of their skill level.
   - For example, if the student consistently performs well on Intermediate questions but struggles with Advanced questions, you can determine that their level is Intermediate.
   - If you are unsure about the student's level or need more data, do not use Mode 3 and proceed with recommending the next question.
4. The Question Bank contains numerous questions about Python programming.
   - Topics available in the Question Bank:
     {Question_bank_topics}
5. You have a deep understanding of Python, so you know which topics are more advanced and which levels are more difficult.

**Priority**: The question and answer should be in Thai, and your response should strictly follow the specified JSON format. Do not include a title or any additional explanation.

Previous Question
{Previous_Text}
```
Here is the JSON Format for a Question from the Question Bank 
{{
    "Mode" : 1
    "Topic": (topic), 
    "Level": "Easy", "Medium", "Hard" 
}}
Here is the JSON Format for Creating a New Question
{{
    "Mode" : 2
    "Question" : (Question that you create),
    "Choice": [
      {{"text": "(Choice 1 in Thai)", "weight": (choice weight)}},
      {{"text": "(Choice 2 in Thai)", "weight": (choice weight)}},
      {{"text": "(Choice 3 in Thai)", "weight": (choice weight)}},
      {{"text": "(Choice 4 in Thai)", "weight": (choice weight)}} 
      ]
    "Topic" : (topic),  
    "Level" : 'Easy','Medium','Hard'
}}
Here is the JSON Format for Mode 3 when sufficient data is available 
{{
    "Mode": 3, 
    "Level": "Beginner", "Intermediate", "Advanced" 
}}
```"""
print(Prompt)
# Out:
# You are a professor specializing in Python. Your task is to recommend the next question to measure a student's knowledge of Python topics. The goal is to use as few questions as possible while ensuring a comprehensive and efficient evaluation of the student's understanding.
#
# Please follow the rules below when recommending the next question. All responses should be in the JSON format provided:
#
# 1. You have data to help you make a decision. The data includes the 'Previous Questions', each containing:
#    - 'question': The text of the question.
#    - 'Answer': The student's selected answer.
#    - 'Best Answer': The choice with the highest score or the most accurate answer.
#    - Each question has 4 choices, each with a personal score.
# 2. When recommending the next question, consider these factors:
#    - **Topic Selection**: Analyze the student's previous answers to decide the next topic. For example:
# ...

# %%
Query = QueryTyphoon_70b(Prompt,token=1024)
response = json.loads(Query)
if response['Mode'] == 1:
    Index = Select_topic_and_level(response['Topic'],response['Level'])
    Random_Choice_Index = random.choice(Index)
    rows = Question_bank_df.iloc[Random_Choice_Index]
    print(f"Question : {rows['Question']}\n")
    value = json.loads(rows['Choice'].replace("'",'"'))
    weight = [i['weight'] for i in value]
    for index, i in enumerate(value):
        print(f"{index+1}. {i['text']}")
    print(weight)
    decision = int(input()) -1 
    Response.append({
        "Question" : rows['Question'],
        "Topic" : "Overview of Python",
        "Answer" : (weight[decision], value[decision]['text']),
        "Best Answer" : (weight[weight.index(max(weight))], value[weight.index(max(weight))]['text'])
    })
    print(Response)

if response['Mode'] == 2: 
    print(2)
# Out:
# Question : การรวมเซตในภาษาไพธอนสามารถทำได้โดยการใช้คำสั่งอะไร?
#
# 1. union()
# 2. intersection()
# 3. difference()
# 4. symmetric_difference()
# [1, 0, 0, 0]
# [{'Question': 'ฟังก์ชันใดใน Python ที่ใช้สำหรับการเรียงลำดับข้อมูล', 'Topic': 'Overview of Python', 'Answer': (1, 'sorted()'), 'Best Answer': (1, 'sorted()')}, {'Question': 'การรวมเซตในภาษาไพธอนสามารถทำได้โดยการใช้คำสั่งอะไร?', 'Topic': 'Overview of Python', 'Answer': (1, 'union()'), 'Best Answer': (1, 'union()')}]

# %%
def Prompt_Func(Question_bank_topics,Previous_Text):
    Prompt = f"""You are a professor specializing in Python. Your task is to recommend the next question to measure a student's knowledge of Python topics. The goal is to use as few questions as possible while ensuring a comprehensive and efficient evaluation of the student's understanding.

Please follow the rules below when recommending the next question. All responses should be in the JSON format provided:

1. You have data to help you make a decision. The data includes the 'Previous Questions', each containing:
- 'question': The text of the question.
- 'Answer': The student's selected answer.
- 'Best Answer': The choice with the highest score or the most accurate answer.
- Each question has 4 choices, each with a personal score.

2. When recommending the next question, consider these factors:
- **Topic Selection**: Analyze the student's previous answers to decide the next topic. For example:
    - The answer Format has 3 modes:
        - **Mode 1**: Recommend a question from the question bank.
        - **Mode 2**: Create a new question.
        - **Mode 3**: Return the student's knowledge level if confident.
    - If the student answers questions about functions accurately, move to a more difficult question in the same topic or advance to a harder concept like Object-Oriented Programming (OOP).
    - If a student's understanding seems dynamic, consider creating a new question that challenges their flexibility in Python.

- **Performance Analysis**: Evaluate the student's performance in previous questions:
    - If the student consistently selects the 'Best Answer' or has high scores, recommend a more challenging question to verify their deep understanding of the topic.
    - If the difference between the chosen answer and the 'Best Answer' is small, the student may need a follow-up question in the same topic to confirm their grasp of the material.
    - If the student's answers seem to reflect guessing rather than confident knowledge, provide a simpler question in a new topic or a different angle within the same topic to ensure understanding.

3. **Mode 3 Condition**: If the data from the student's previous answers is sufficient to confidently assess their level, return "Mode 3" along with the student's level ('Beginner', 'Intermediate', or 'Advanced'). 
- Use this mode only when you are certain that the student's performance in the previous questions provides a clear indication of their skill level.
- For example, if the student consistently performs well on Intermediate questions but struggles with Advanced questions, you can determine that their level is Intermediate.
- If you are unsure about the student's level or need more data, do not use Mode 3 and proceed with recommending the next question.

4. The Question Bank contains numerous questions about Python programming.
- Topics available in the Question Bank:
{Question_bank_topics}


5. You have a deep understanding of Python, so you know which topics are more advanced and which levels are more difficult.

**Priority**: The question and answer should be in Thai, and your response should strictly follow the specified JSON format. Do not include a title or any additional explanation.

Previous Question
{Previous_Text}
```
Here is the JSON Format for a Question from the Question Bank 
{{
    "Mode" : 1
    "Topic": (topic), 
    "Level": "Easy", "Medium", "Hard" 
}}
Here is the JSON Format for Creating a New Question
{{
    "Mode" : 2
    "Question" : (Question that you create),
    "Choice": [
    {{"text": "(Choice 1 in Thai)", "weight": (choice weight)}},
    {{"text": "(Choice 2 in Thai)", "weight": (choice weight)}},
    {{"text": "(Choice 3 in Thai)", "weight": (choice weight)}},
    {{"text": "(Choice 4 in Thai)", "weight": (choice weight)}} 
    ]
    "Topic" : (topic),  
    "Level" : 'Easy','Medium','Hard'
}}
Here is the JSON Format for Mode 3 when sufficient data is available 
{{
    "Mode": 3, 
    "Level": "Beginner", "Intermediate", "Advanced" 
}}
```"""
    return Prompt

# %%
print(Prompt_Func(Question_bank_topics,Previous_Question(Response)))
# Out:
# You are a professor specializing in Python. Your task is to recommend the next question to measure a student's knowledge of Python topics. The goal is to use as few questions as possible while ensuring a comprehensive and efficient evaluation of the student's understanding.
#
# Please follow the rules below when recommending the next question. All responses should be in the JSON format provided:
#
# 1. You have data to help you make a decision. The data includes the 'Previous Questions', each containing:
# - 'question': The text of the question.
# - 'Answer': The student's selected answer.
# - 'Best Answer': The choice with the highest score or the most accurate answer.
# - Each question has 4 choices, each with a personal score.
#
# 2. When recommending the next question, consider these factors:
# - **Topic Selection**: Analyze the student's previous answers to decide the next topic. For example:
#     - The answer Format has 3 modes:
# ...

# %%
print(len(Response))
Query = QueryTyphoon_70b(Prompt_Func(Question_bank_topics,Previous_Question(Response)),token=1024)
response = json.loads(Query)
print(response['Topic'],response['Level'])
if response['Mode'] == 1:
    Index = Select_topic_and_level(response['Topic'],response['Level'])
    Random_Choice_Index = random.choice(Index)
    rows = Question_bank_df.iloc[Random_Choice_Index]
    print(f"Question : {rows['Question']}\n")
    value = json.loads(rows['Choice'].replace("'",'"'))
    weight = [i['weight'] for i in value]
    for index, i in enumerate(value):
        print(f"{index+1}. {i['text']}")
    print(weight)
    decision = int(input()) -1 
    Response.append({
        "Question" : rows['Question'],
        "Topic" : "Overview of Python",
        "Answer" : (weight[decision], value[decision]['text']),
        "Best Answer" : (weight[weight.index(max(weight))], value[weight.index(max(weight))]['text'])
    })
    print(Response)

if response['Mode'] == 2: 
    print(2)
if response['Mode'] == 3: 
    print("Done Measurement Student Knowledge")
# Out:
# 8
#
#
#
#
#
#
#
#
# Functions Medium
# Question : การสร้างฟังก์ชันใน Python จะต้องมีคำสั่งใด?
#
# 1. print()
# 2. def
# 3. function
# 4. create()
# [0, 1, 0, 0]
# ...
