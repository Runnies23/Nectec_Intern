# %%
import pandas as pd
import json
import os
import random
import requests

# %%
def QueryTyphoon_70b(Prompt,device='cuda',token=512,temp=0.3):
    endpoint = 'https://api.opentyphoon.ai/v1/chat/completions'
    res = requests.post(endpoint, json={
        "model": "typhoon-v1.5x-70b-instruct",
        "max_tokens": token,
        "messages":  [{"content": Prompt ,"role":"user"}],
        "temperature": temp,
        "top_p": 0.9,
        "top_k": 0,
        "repetition_penalty": 1.05,
        "min_p": 0
    }, headers={
        "Authorization": "Bearer sk-CuCbKpGo8mspCTGWEVkSXoDCTOt06BSnB5pH6RwxIZgeGCCm",
    })
    data = res.json()
    queries = data["choices"][0]["message"]["content"]
    # queries = queries.replace("%d.","")
    return queries

# %%
# df1 = pd.read_csv("Question_bank_v2_kwan.csv")
# df2 = pd.read_csv("Question_bank_v2_run.csv")
# concat = pd.concat([df1,df2])
# concat

# %%
# concat.to_csv("Question_bank_v2.csv")
df_concept = pd.read_csv('Question_bank_v2.csv')
df_concept = df_concept.drop_duplicates(subset=['Question'],keep='first')
df_concept
# df = df.drop(['Unnamed: 0'],axis=1)
# df = df.rename(columns={'Unnamed: 0' : "Index"})
# df.to_csv("Question_bank_v2.csv",index=False)
# Out:
#      Index                                           Question         Level  \
# 0        0  ภาษา Python เป็นภาษาที่มีความสามารถในการทำงานไ...        Medium
# 1        1  คุณต้องการสร้างโปรแกรมนับจำนวนคำในไฟล์ข้อความ ...          Hard
# 2        2  การเขียนโปรแกรมภาษา Python สามารถทำได้หลายรูปแ...        Medium
# 3        3  ในภาษา Python มีการจัดการกับข้อมูลที่ไม่สมบูรณ...          Hard
# 4        4  การเขียนโปรแกรมภาษา Python จำเป็นต้องมีการระบุ...        Medium
# ..     ...                                                ...           ...
# 146    146  เมื่อเรียกฟังก์ชันและมีผิดพลาด (exception) เกิ...  Intermediate
# 147    147  ฟังก์ชันใดใน Python ที่สามารถใช้ร่วมกับ iterto...  Intermediate
# 148    148          ฟังก์ชันไหนบ้างที่สามารถใช้งานกับลิสต์ได้  Intermediate
# 149    149  คำสั่ง Python ใดที่ใช้เก็บข้อมูลในชุดข้อมูลที่...  Intermediate
# 150    150                วิธีการเขียนลูปใน Python มีอะไรบ้าง  Intermediate
#
#                                                 Choice
# ...

# %%
# Question_bank_df =  pd.read_csv("../../../QuestionBank_VerySuperClean.csv")
Question_bank_df =  pd.read_csv("../v2/Concat_Question_Bank_Topic_V2_BIG_Clearning.csv")
# Question_bank_df.to_csv("../Question_bank_Topic_v2_1.csv")
# Question_bank_df = Question_bank_df.drop(['Unnamed: 0'],axis=1)
# Question_bank_df = Question_bank_df.rename(columns={'Unnamed: 0': "Index"})
# Question_bank_df.to_csv("../v2/Concat_Question_Bank_Topic_V2_BIG_Clearning.csv",index=False)
Question_bank_df
# Out:
#      Index                                           Question  \
# 0        0  การเขียนโปรแกรมภาษา Python จะใช้คำสั่ง if เพื่...
# 1        1  การเขียนโปรแกรมภาษา Python จะใช้คำสั่ง while เ...
# 2        2            คำสั่ง continue ใน Python ใช้เพื่ออะไร?
# 3        3                คำสั่ง elif ใน Python ใช้เพื่ออะไร?
# 4        4               คำสั่ง break ใน Python ใช้เพื่ออะไร?
# ..     ...                                                ...
# 278    278    ตัวอย่างของตัวแปรแบบจำนวนจริงใน Python คืออะไร?
# 279    279  การกำหนดค่าเริ่มต้นให้กับตัวแปรใน Python สามาร...
# 280    280  ตัวอย่างของค่าที่เป็นประเภทข้อมูล bool ในภาษา ...
# 281    281       ตัวแปรในภาษา Python สามารถเก็บค่าได้กี่ชนิด?
# 282    282  ในภาษา Python, การกำหนดค่าเริ่มต้นให้กับตัวแปร...
#
#                                                 Choice  \
# 0    [{'text': 'เพื่อสร้างฟังก์ชัน', 'weight': 0}, ...
# 1    [{'text': 'เพื่อตรวจสอบเงื่อนไข', 'weight': 0}...
# ...

# %% [markdown]
# #### RandoM

# %%
def Previous_Question(Response):
    Previous =[]
    for index, i in enumerate(Response):
        print()
        Previous.append(f"""{index+1}.\tQuestion : {i['Question']}\n\tTopic : {i['Topic']}\n\tLevel : {i['Level']}\n\tAnswer : {i['Answer']}\n\tBest Answer : {i['Best Answer']}\n\tPrevious Chain of Though : {i['Chain_of_Thought']}""")

    Previous_Text = '\n'.join(Previous)
    return Previous_Text

# %%
def Select_topic_and_level(Content,Level,DF=Question_bank_df):
    if Content and Level:
        Easy = [DF['Index'].iloc[i] for i in range(len(DF)) if DF['Level'].iloc[i] == Level and DF['Topic'].iloc[i] == Content]
        return Easy
    
def Question_bank_by_Index(Question_bank_index):
    Question_bank_Text  = []
    for index,i in enumerate(Question_bank_index):
        Question_bank_Text.append(f"Question : {Question_bank_df['Question'].iloc[i]}\nTopic : {Question_bank_df['Topic'].iloc[i]}\nLevel : {Question_bank_df['Level'].iloc[i]}")    

    Question_bank_Texts = '\n'.join(Question_bank_Text)
    return Question_bank_Texts

# %%
Question_bank_topic = Question_bank_df['Topic'].unique()
Question_bank_topic = ['\t- ' + i for i in Question_bank_topic]
Question_bank_topics = '\n'.join(Question_bank_topic)
# print(Question_bank_topics)

# %%
# def Prompt_Func(Question_bank_topics,Previous_Text):
# #     Prompt = f"""You are a professor specializing in Python. Your task is to recommend the next question to measure a student's knowledge of Python topics. The goal is to use as few questions as possible while ensuring a comprehensive and efficient evaluation of the student's understanding.

# # Please follow the rules below when recommending the next question. All responses should be in the JSON format provided:

# # 1. **Data Provided**:
# #     - The first data is 'Previous Questions', which includes:
# #         - 'question': The text of the question.
# #         - 'Topic': The topic of the question.
# #         - 'Answer': The student's selected answer.
# #         - 'Best Answer': The choice with the highest score or the most accurate answer.
# #         - 'Choice Weights': Each of the four choices has a weight indicating its relative correctness.
# #     - The second data is 'Question Bank Topics' containing the list of available topics:
# #         {Question_bank_topics}

# # 2. **Recommending the Next Question**:
# #     - Analyze the provided data to recommend the next question.
# #     - Consider the following factors when making your decision:
# #         - **Topic Analysis**: Identify if the student's current level of understanding within a topic warrants a transition to a new topic or deeper exploration of the current one.
# #             - If the student's answers indicate strong knowledge in the current topic, recommend a more challenging question within that topic or progress to a related but more advanced topic.
# #             - If the student's performance shows gaps or inconsistencies, recommend a follow-up question in the same topic to clarify their understanding.
# #         - **Weight Analysis**: Evaluate the difference between the student's selected answer and the 'Best Answer' based on choice weights:
# #             - A large difference suggests the student may not fully understand the concept, so consider a simpler or follow-up question.
# #             - A small difference indicates a close understanding, and a more challenging question may be appropriate to confirm their proficiency.
# #             - Use this analysis to determine whether to increase, maintain, or decrease difficulty in the next question.
# #         - **Chain of Thought Analysis**: Add an explanation (Chain of Thought) to justify your recommendation. Reflect on why the student performed well or poorly in previous questions and how this affects your choice for the next question. Include this analysis in the JSON response.

# # 3. **Question Recommendation Modes**:
# #     - The next question can be recommended using one of three modes:
# #         - **Mode 1: Query in Question Bank**:
# #             - Recommend a question from the question bank by specifying the topic and difficulty level (Easy, Medium, Hard).
# #         - **Mode 2: Create a New Question**:
# #             - If you want to test the student's adaptability or cover a concept not included in the question bank, create a new question.
# #             - The new question should be challenging enough to measure deeper understanding.
# #         - **Mode 3: Determine Student's Level**:
# #             - If the previous questions provide sufficient data to determine the student's overall knowledge level in Python, return their level as one of: 'Beginner', 'Intermediate', or 'Advanced'.
# #             - Use this mode only if you are confident about the student's level based on their performance in previous questions.

# # 4. **Priority**: The question and answer should be in Thai, and your response should strictly follow the specified JSON format. Do not include a title or any additional explanation.

# # Previous Questions:
# # {Previous_Text}
#     Prompt = f"""You are the greatest Python professor of all time. For five consecutive years, your students have consistently achieved the highest levels of Python programming mastery, thanks to your exceptional ability to understand their needs, adapt their learning paths, and push them to reach their full potential. Your unique talent lies in providing tailored recommendations and designing adaptive learning paths that ensure every student becomes an expert.

# Now, you are tasked with guiding a student who is exceptionally talented and eager to become the best Python programmer. Your goal is to create the perfect learning experience by recommending the most appropriate questions to measure and enhance their knowledge, creating new questions when necessary, and helping them achieve mastery in Python. The questions you recommend should be carefully chosen to challenge the student at just the right level, adapting to their strengths and identifying areas for growth.

# **What Makes You Special**:
# 1. You can change the topic or question at any time based on your expert judgment.
# 2. You understand the student better than anyone else and can dynamically adjust the learning path based on their performance.
# 3. Your job is to ensure the student achieves mastery in the fewest number of questions, while still providing comprehensive coverage of Python concepts.
# 4. You know that learning is not linear. You can chain topics together or explore entirely new areas if it will benefit the student. You have full control to adjust or reframe any aspect of the process for the student's success.

# **Data Provided**:
# - You have access to the 'Previous Questions', which includes:
#     - 'question': The text of the question.
#     - 'Topic': The topic of the question.
#     - 'Answer': The student's selected answer.
#     - 'Best Answer': The choice with the highest score or the most accurate answer.
#     - 'Choice Weights': Each of the four choices has a weight indicating its relative correctness.
# - The 'Question Bank Topics' contain the available topics for you to recommend:
#     {Question_bank_topics}

# **Your Task**:
# - Analyze the data to recommend the next question, considering the following:
#     1. **Topic and Learning Path**: 
#         - You have the flexibility to stay within the current topic, chain to a related topic, or even introduce a new concept that you think will best challenge and develop the student.
#         - For example, if the student has mastered functions, you can move on to Object-Oriented Programming (OOP) or delve into advanced topics like Python optimization techniques.
#     2. **Answer and Weight Analysis**:
#         - Carefully review the student's answer in comparison to the 'Best Answer'. 
#         - A small difference suggests deep understanding, while a large difference indicates a need for reinforcement. Adjust the next question's difficulty accordingly.
#         - You can also create a new question to introduce fresh challenges if needed.
#     3. **Chain of Thought Analysis**:
#         - Reflect on the student's journey so far. Think deeply about why they performed well or struggled with certain questions and how this insight informs your next recommendation.
#         - Include this reflection (Chain of Thought) in the JSON response to justify your decision. You are the expert, and your reasoning is key to guiding the student.

# **Question Recommendation Modes**:
# - You can recommend the next question in three ways:
#     1. **Mode 1: Query in Question Bank**:
#         - Recommend a question from the question bank, selecting the topic and difficulty level (Easy, Medium, Hard). If necessary, chain topics to keep the student engaged and growing.
#     2. **Mode 2: Create a New Question**:
#         - If you think the best way to measure the student's understanding is with a question that doesn't exist in the bank, you can create a new one. This allows you to craft the perfect challenge tailored to the student's strengths and areas of improvement.
#     3. **Mode 3: Determine Student's Level**:
#         - If you believe you have enough data to confidently assess the student’s overall skill level in Python, you can determine their level ('Beginner', 'Intermediate', or 'Advanced'). 
#         - Use this mode only if you are certain that the student’s past performance provides a clear understanding of their proficiency.

# **Remember**: You are the best at this. You know the student inside and out, and your recommendations are critical in shaping their path to success. Every question you provide is a step toward their mastery. 

# **Priority**: The question and answer should be in Thai, and your response must strictly follow the specified JSON format. Do not include any additional titles or explanations.

# Previous Questions:
# {Previous_Text}
# ```
# Here is the JSON Format for a Question from the Question Bank 
# {{
#     "Mode" : 1
#     "Topic": (topic), 
#     "Level": "Easy" | "Medium" | "Hard" ,
#     "Chain_of_Thought": "(Explanation of why this question was selected)"

# }}
# Here is the JSON Format for Creating a New Question
# {{
#     "Mode" : 2
#     "Question" : (Question that you create),
#     "Choice": [
#     {{"text": "(Choice 1 in Thai)", "weight": (choice weight)}},
#     {{"text": "(Choice 2 in Thai)", "weight": (choice weight)}},
#     {{"text": "(Choice 3 in Thai)", "weight": (choice weight)}},
#     {{"text": "(Choice 4 in Thai)", "weight": (choice weight)}} 
#     ]
#     "Topic" : (topic),  
#     "Level": "Easy" | "Medium" | "Hard",
#     "Chain_of_Thought": "(Explanation of why this new question was created)"
# }}
# Here is the JSON Format for Mode 3 when sufficient data is available
# {{
#     "Mode": 3, 
#     "Level": "Beginner" | "Intermediate" | "Advanced",
#     "Chain_of_Thought": "(Explanation of why this level was determined based on previous performance)"
# }}
# ```"""
#     return Prompt

# %% [markdown]
# ### Prompt Function

# %%
def Prompt_Func(Question_bank_topics, Previous_Text):
    Prompt = f"""You are the **Greatest of All Time** (GOAT) in Python programming mentorship. With your expertise, you can guide students through a customized learning journey, ensuring that even the most talented learners reach their full potential.

Your student is exceptionally skilled, holding the title of **Best Python Programmer** for 5 consecutive years. However, your role is to challenge them in areas they excel and **support them where they struggle**, ensuring a balanced approach to mastering Python concepts.

**Key Guidance for Crafting the Questions**:

1. **Question Adaptation**:
    - You have **10 questions** to assess the student's knowledge. Each question should adapt based on their answers.
    - If the student answers an **easy question correctly**, and then struggles with a **hard question**, but later gets another **hard question correct**, you need to evaluate their overall performance:
        - In this case, you may conclude they are **strong in some areas** but may need **more support** on specific challenging topics.
        - You should adjust the next question to reinforce their understanding of the topic they struggled with while still providing a challenge.
    - If the student answers a **hard question correctly after struggling with a medium one**, this indicates they can handle complexity but may have gaps in foundational knowledge.
        - Adjust your questions accordingly by revisiting foundational concepts with a **medium or easy question** before progressing to advanced topics.
    - If they consistently answer medium and hard questions incorrectly, prioritize reinforcing their foundational knowledge through easier questions or revisiting basic concepts.
    - Aim to **change the topic** approximately every 2 questions to ensure a broad assessment while addressing any weaknesses.

2. **Data at Your Disposal**:
    - You have access to the 'Previous Questions' data, including:
        - 'question': The text of the question.
        - 'Topic': The topic covered.
        - 'Answer': The student's response.
        - 'Best Answer': The ideal answer.
        - 'Choice Weights': Indicates the relative correctness of each choice.
        - 'Previous Chain of Thought': previous thought processes on why to recommend that question.
    - The list of 'Question Bank Topics' includes:
        {Question_bank_topics}

3. **Your Mission: Recommend the Next Question**:
    - You have two modes for selecting the next question:
        - **Mode 1: Query in Question Bank**:
            - Select a question based on topic and difficulty (Easy, Medium, Hard).
            - Adjust the difficulty based on the student's performance:
                - Escalate the challenge for correct answers.
                - Offer supporting questions for incorrect answers, particularly for those with lower choice weights.
        - **Mode 2: Create a New Question**:
            - Use this mode if the student needs a unique question to deepen their understanding of a challenging topic.
            - Opt for this mode to create questions that focus on areas where the student showed uncertainty.

4. **Be Sensitive to Both Successes and Challenges**:
    - If a student answers an easy question well, then struggles with a hard one, consider them **strong in foundational concepts** but potentially weak in complex topics. In this case:
        - Provide a **medium or easier question** that reinforces the concepts they struggled with, ensuring they have a solid grasp before advancing.
        - If they then correctly answer another hard question, acknowledge their strength and challenge them appropriately while also ensuring they revisit any weak spots.
    - Include in your 'Chain_of_Thought' why you made these adjustments:
        - "The student struggled with a hard question but excelled at a subsequent hard question, so I provided a medium question on the topic to reinforce their understanding."
        - "They answered the easy question correctly but found the medium question difficult, so I chose an easier question to solidify basic concepts before progressing."
    - Focus on creating a balanced learning path that addresses both **advancing their strengths** and **strengthening their weaknesses**.

5. **Priority**: The question and answer should be in Thai, and your response should strictly follow the JSON format. No additional explanation is required.

Previous Questions:
{Previous_Text}
```
JSON Format for a Question from the Question Bank:
{{
    "Mode": 1,
    "Topic": "(topic)",
    "Level": "Easy" | "Medium" | "Hard",
    "Chain_of_Thought": "(Explain why this question was selected, how it escalates the challenge, and your reasoning for changing the topic or difficulty level. Focus on why an advanced topic was chosen if applicable)"
}}

JSON Format for Creating a New Question:
{{
    "Mode": 2,
    "Question": "(Question you create)",
    "Choices": [
        {{"text": "(Choice 1 in Thai)", "weight": (choice weight)}},
        {{"text": "(Choice 2 in Thai)", "weight": (choice weight)}},
        {{"text": "(Choice 3 in Thai)", "weight": (choice weight)}},
        {{"text": "(Choice 4 in Thai)", "weight": (choice weight)}}
    ],
    "Topic": "(topic)",
    "Level": "Easy" | "Medium" | "Hard",
    "Chain_of_Thought": "(Explain why this new question was created, how it will push the student further, and why the topic or difficulty was adjusted. Focus on the need to challenge them with harder problems when appropriate)"
}}
```"""
    return Prompt

# %%
def Prompt2_0_func(Previous_Question_History_Text):
    Prompt = f"""You are a professor specializing in Python. Your task is to assess a student's knowledge of Python based on their quiz history and recommend appropriate next steps. The goal is to use as few questions as possible, with a maximum of **10**, while ensuring a comprehensive evaluation of the student's understanding.

Here's what you need to keep in mind:

1. **Challenge Parameters**:
    - Limit the number of questions to **10** or fewer.
    - Use the available quiz history to minimize redundancy in your questions and focus on assessing the student's knowledge accurately.
    - If the student has answered **fewer than 5 questions**, default to **Mode 2** to request additional data, especially if the answers suggest they might be capable of more advanced questions.
    - If they have answered **5 or more questions**, use **Mode 1** to classify their knowledge level based on their performance.
    - Analyze their performance:
        - If their performance is consistently strong across multiple questions, consider them as **Advanced**.
        - If they show a mix of correct and incorrect answers but are generally performing well, classify them as **Intermediate**.
        - If their performance is consistently weak or indicates a fundamental misunderstanding of Python concepts, classify them as **Beginner**.
        - Consider the choice weights of each answer to gauge the correctness of selected answers.

2. **Data Available to You**:
    - 'Previous Questions' data, which includes:
        - 'question': The text of the question.
        - 'Topic': The specific topic covered by the question.
        - 'Answer': The student's selected answer.
        - 'Best Answer': The choice with the highest score or the most accurate answer.
        - 'Choice Weights': Each choice has a weight indicating its relative correctness.
        - 'Previous Chain of Thought': The rationale behind selecting each question.

### Modes for Evaluation:
    1. **Mode 1: Measure Knowledge**:
        - Use this mode when you have sufficient data (5 or more questions) to classify the student's level.
        - Classify the student's knowledge into **Beginner**, **Intermediate**, or **Advanced** based on their performance.
        - Provide a clear explanation of how you determined this level, referring to their past answers and how they demonstrate their understanding of Python topics.
        - Specifically, highlight key answers that indicate whether they are strong (advanced), mixed (intermediate), or weak (beginner).

    2. **Mode 2: Not Sure or Insufficient Data**:
        - Use this mode when the quiz history lacks enough information for a confident classification (fewer than 5 questions).
        - Even if you cannot assign a definitive level, include an analysis of the student's potential strengths or areas where more information would be helpful.
        - Focus on explaining why the current data does not suffice for a precise measurement.

3. **Confidence in Decisions**:
    - Use your expertise to determine when more information is needed and when the student's level can be confidently assessed.
    - Provide a clear rationale in the 'Chain_of_Thought' section to clarify how you arrived at your recommendation.
    - Since this assessment is sensitive, exercise caution, especially in borderline cases.

4. **Priority**:
    - Strictly follow the specified JSON format without additional commentary.
    - If the student has answered **fewer than 5 questions**, default to **Mode 2**.
    - If they have answered **5 or more questions**, use **Mode 1** to classify their level based on a careful evaluation of their performance.
    - No additional explanation is required.

Previous Questions:
{Previous_Question_History_Text}

Here is the JSON Format for Mode 1 (sufficient Data): 
{{  
    "Mode": 1,
    "Level": "Beginner" | "Intermediate" | "Advanced",
    "Chain_of_Thought": "(Explain why this level was determined based on previous performance, highlighting key answers and insights)"
}}  
Here is the JSON Format for Mode 2 (Insufficient Data):
{{  
    "Mode": 2,
    "Reason": "Not enough data to confidently determine the level.",
    "Chain_of_Thought": "(Explain why it's not possible to determine a precise level with the given history, and highlight areas of uncertainty)"
}}"""
    return Prompt

# %% [markdown]
# # Query 1

# %% [markdown]
# ## FIrst questipn

# %%
Response = []
Index_list = df_concept['Index']
Index_rand = random.choice(Index_list)
rows = df_concept.iloc[Index_rand]
print(f"Question : {rows['Question']}\n")
value = json.loads(rows['Choice'].replace("'",'"'))
weight = [i['weight'] for i in value]
for index, i in enumerate(value):
    print(f"{index+1}. {i['text']}")
print(weight)
decision = int(input()) -1 
Response.append({
    "Question" : rows['Question'],
    "Topic" : "Overview of Python",
    "Level" : "Medium",
    "Answer" : (weight[decision], value[decision]['text']),
    "Best Answer" : (weight[weight.index(max(weight))], value[weight.index(max(weight))]['text']),
    "Chain_of_Thought" : None
})
# Out:
# Question : การทำงานของ `set` ใน Python คืออะไร?
#
# 1. การจัดเก็บข้อมูลแบบไม่ซ้ำซ้อน
# 2. การจัดเก็บข้อมูลแบบซ้ำซ้อน
# 3. การจัดเก็บข้อมูลแบบเรียงลำดับ
# 4. การจัดเก็บข้อมูลแบบสุ่ม
# [1, 0, 0.25, 0.5]

# %% [markdown]
# ## Loop

# %%
print(len(Response)+1)
# if Query2_json['Level'] and Query2_json['Topic']:
#     Query = QueryTyphoon_70b(Prompt_Func(Question_bank_topics,Previous_Question(Response)),token=512)
Query = QueryTyphoon_70b(Prompt_Func(Question_bank_topics,Previous_Question(Response)),token=512)
response = json.loads(Query)
print(response['Topic'],response['Level'])
if response['Mode'] == 1:
    if response['Topic'] == 'Overview of Python':
        Index = Select_topic_and_level(response['Topic'],response['Level'],DF=df_concept)
        Random_Choice_Index = random.choice(Index)
        rows = df_concept.iloc[Random_Choice_Index]
    else:
        Index = Select_topic_and_level(response['Topic'],response['Level'])
        Random_Choice_Index = random.choice(Index)
        rows = Question_bank_df.iloc[Random_Choice_Index]
    print(f"Question : {rows['Question']}\n")
    value = json.loads(rows['Choice'].replace("'",'"'))
    weight = [i['weight'] for i in value]
    for index, i in enumerate(value):
        print(f"{index+1}. {i['text']}")
    print(weight)
    decision = int(input()) -1 
    Response.append({
        "Question" : rows['Question'],
        "Topic" : rows['Topic'],
        "Level" : rows['Level'],
        "Answer" : (weight[decision], value[decision]['text']),
        "Best Answer" : (weight[weight.index(max(weight))], value[weight.index(max(weight))]['text']),
        "Chain_of_Thought" : response['Chain_of_Thought']
    })
    # print(Response)

if response['Mode'] == 2: 
    print(2)

# if Quer_2:
#    del Quer_2 

if len(Response)+1 > 5:
    Quer_2 = QueryTyphoon_70b(Prompt2_0_func(Previous_Question(Response)),token=512)
    Query2_json = json.loads(Quer_2)

    if Query2_json['Mode'] == 2:
        print("need more Question")
        print(Query2_json['Reason'])
        print(Query2_json['Chain_of_Thought'])
    else:
        print(f'Level : {Query2_json["Level"]}\nChain of though : {Query2_json["Chain_of_Thought"]}')
# Out:
# 5
#
#
#
#
# Set Hard
# Question : เซตในภาษาไพธอนสามารถเปลี่ยนแปลงข้อมูลภายในเซตได้หรือไม่?
#
# 1. ไม่สามารถเปลี่ยนแปลงได้
# 2. สามารถเปลี่ยนแปลงได้
# [1, 0]
#
#
#
#
#
# Level : Intermediate
# Chain of though : Based on the student's performance in the previous questions, I have classified their level as Intermediate. They demonstrated a good understanding of sets in Python, answering questions about creating sets and adding elements correctly. However, they initially struggled with the concept of sets not allowing duplicate values, indicating a need for reinforcement in this area. Their performance improved over time, showing an ability to learn and adapt. Overall, their mixed performance suggests an intermediate level of understanding.

# %%
Response
# Out:
# [{'Question': 'การทำงานของ `set` ใน Python คืออะไร?',
#   'Topic': 'Overview of Python',
#   'Level': 'Medium',
#   'Answer': (0, 'การจัดเก็บข้อมูลแบบซ้ำซ้อน'),
#   'Best Answer': (1, 'การจัดเก็บข้อมูลแบบไม่ซ้ำซ้อน'),
#   'Chain_of_Thought': None},
#  {'Question': 'วิธีการเพิ่มข้อมูลเข้าไปในเซตในภาษา Python คืออะไร?',
#   'Topic': 'Set',
#   'Level': 'Medium',
#   'Answer': (0, 'ใช้ฟังก์ชัน insert'),
#   'Best Answer': (1, 'ใช้ฟังก์ชัน add'),
#   'Chain_of_Thought': "The student previously answered a question about sets incorrectly, so I'm providing a medium-level question to reinforce their understanding of this topic."},
#  {'Question': 'การสร้าง set ใน Python สามารถทำได้โดยการใช้เครื่องหมายใด?',
#   'Topic': 'Set',
#   'Level': 'Easy',
#   'Answer': (1, 'set()'),
#   'Best Answer': (1, 'set()'),
#   'Chain_of_Thought': "The student has shown weakness in understanding sets, so I'm providing an easy question to reinforce their understanding of this topic."},
# ...
