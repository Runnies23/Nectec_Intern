# %%
import pandas as pd

# %%
df = pd.read_csv("100question.csv")
df
# Out:
#                                              Question  \
# 0   การสร้างเเชทGPT มีเป้าหมายหลักอย่างไร และแตกต่...
# 1   GPT ใช้วิธีการ pre-training และ fine-tuning อย...
# 2   การสร้างแบบจำลองภาษาที่ปิดหน้ามีส่วนสำคัญอย่าง...
# 3   กลไกการโฟกัสในทรานส์ฟอร์เมอร์มีความสำคัญอย่างไ...
# 4   GPT จัดการกับคำหรือโทเค็นที่ไม่ได้อยู่ในฐานข้อ...
# ..                                                ...
# 95  เปรียบเทียบและต่างกันระหว่างโมเดล GPT-1, GPT-2...
# 96  อธิบายถึงความเสี่ยงและข้อพิจารณาเชิงจริยธรรมที...
# 97  อธิบายสถานการณ์ที่ GPT สามารถใช้สร้างเนื้อหาที...
# 98  การเรียนรู้แบบเสริมแรงสามารถผสมผสานกับ GPT อย่...
# 99  เมตริกประเมินผลใดที่ใช้ในการประเมินประสิทธิภาพ...
#
#                                               Choice1  \
# 0                ('เพื่อสร้างบทสนทนาแบบมนุษย์', 0.75)
# 1             ('โดยใช้ข้อมูลขนาดใหญ่ในการฝึกฝน', 0.5)
# 2   ('ช่วยให้โมเดลสามารถเรียนรู้คำศัพท์และความหมาย...
# 3   ('ช่วยให้โมเดลสามารถโฟกัสที่ส่วนสำคัญของข้อมูล...
# ...
