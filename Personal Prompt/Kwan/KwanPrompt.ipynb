# %%
Topic = ""
Prompt = f"""You are a planner teacher for student learning. The Student want to learn how to {Topic}. So create a guideline what should he learning for {Topic}
write the answer in the Json format
```
  
```
"""
print(Prompt)
# Out:
# You are a planner teacher for student learning. The Student want to learn how to . So create a guideline what should he learning for
# write the answer in the Json format
# ```
#
# ```

# %%
#generate 10 question 
Topic = "create 10 question about chemistry"

Prompt = f"""you are chem teacher who create exam for secondary student  {Topic}. So Create a guideline what should he learning for {Topic} so create chemistry quiz about org chem for secondary student
write the Answer in the Json format and English Language 

'Question1' : ['Question' :'q1',
                    'Choice' : [
                        'Choice1' : 'q1',
                        'Choice2' : 'q1',
                        'Choice3' : 'q1',
                        'Choice4' : 'q1'
                    ]],
                    
    'Question2' : ['Question' :'q2',
                    'Choice' : [
                        'Choice1' : 'q2',
                        'Choice2' : 'q2',
                        'Choice3' : 'q2',
                        'Choice4' : 'q2'
                    ]]
"""
print(Prompt)
# Out:
# you are chem teacher who create exam for secondary student  create 10 question about chemistry. So Create a guideline what should he learning for create 10 question about chemistry so create chemistry quiz about org chem for secondary student
# write the Answer in the Json format and English Language
#
# 'Question1' : ['Question' :'q1',
#                     'Choice' : [
#                         'Choice1' : 'q1',
#                         'Choice2' : 'q1',
#                         'Choice3' : 'q1',
#                         'Choice4' : 'q1'
#                     ]],
#
#     'Question2' : ['Question' :'q2',
#                     'Choice' : [
#                         'Choice1' : 'q2',
#                         'Choice2' : 'q2',
#                         'Choice3' : 'q2',
#                         'Choice4' : 'q2'
#                     ]]

# %%
import json

questions = """{
    'Question2': {
        'Question': 'Which functional group is present in carboxylic acids?',
        'Choice': {
            'Choice1': '-OH',
            'Choice2': '-COOH',
            'Choice3': '-NH2',
            'Choice4': '-CHO'
        }
    },
    'Question3': {
        'Question': 'What is the process of breaking down large molecules into smaller ones called?',
        'Choice': {
            'Choice1': 'Synthesis',
            'Choice2': 'Decomposition',
            'Choice3': 'Catalysis',
            'Choice4': 'Hydrolysis'
        }
    },
    'Question4': {
        'Question': 'Which type of bond is formed by the sharing of electrons between atoms?',
        'Choice': {
            'Choice1': 'Ionic bond',
            'Choice2': 'Covalent bond',
            'Choice3': 'Polar bond',
            'Choice4': 'Hydrogen bond'
        }
    },
    'Question5': {
        'Question': 'What is the name of the process by which an alkane is converted into an alkene?',
        'Choice': {
            'Choice1': 'Dehydration',
            'Choice2': 'Hydration',
            'Choice3': 'Hydrogenation',
            'Choice4': 'Dehydrogenation'
        }
    },
    'Question6': {
        'Question': 'Which of the following compounds is an alcohol?',
        'Choice': {
            'Choice1': 'CH3CH2OH',
            'Choice2': 'CH3CH2CH3',
            'Choice3': 'CH3COCH3',
            'Choice4': 'CH3CH2Cl'
        }
    },
    'Question7': {
        'Question': 'What is the purpose of a catalyst in a chemical reaction?',
        'Choice': {
            'Choice1': 'To increase the temperature of the reaction',
            'Choice2': 'To decrease the activation energy of the reaction',
            'Choice3': 'To change the equilibrium constant of the reaction',
            'Choice4': 'To alter the products of the reaction'
        }
    },
    'Question8': {
        'Question': 'Which of the following is a characteristic of aromatic compounds?',
        'Choice': {
            'Choice1': 'They are highly reactive',
            'Choice2': 'They have a planar ring structure',
            'Choice3': 'They are soluble in water',
            'Choice4': 'They are solid at room temperature'
        }
    },
    'Question9': {
        'Question': 'What is the term for the movement of electrons within a molecule?',
        'Choice': {
            'Choice1': 'Resonance',
            'Choice2': 'Polarization',
            'Choice3': 'Ionization',
            'Choice4': 'Electrophilic attack'
        }
    },
    'Question10': {
        'Question': 'Which of the following reactions involves the addition of water to an alkene?',
        'Choice': {
            'Choice1': 'Hydrogenation',
            'Choice2': 'Halogenation',
            'Choice3': 'Hydration',
            'Choice4': 'Alkylation'
        }
    }
}"""

# Convert to JSON
# 
# print(questions_json)

# %%
# questions=str(questions)
questions= questions.replace("'",'"')
questions_json = json.loads(questions)

# %%
type(str(questions))
# Out:
# str

# %%
print(questions_json)
# Out:
# {'Question2': {'Question': 'Which functional group is present in carboxylic acids?', 'Choice': {'Choice1': '-OH', 'Choice2': '-COOH', 'Choice3': '-NH2', 'Choice4': '-CHO'}}, 'Question3': {'Question': 'What is the process of breaking down large molecules into smaller ones called?', 'Choice': {'Choice1': 'Synthesis', 'Choice2': 'Decomposition', 'Choice3': 'Catalysis', 'Choice4': 'Hydrolysis'}}, 'Question4': {'Question': 'Which type of bond is formed by the sharing of electrons between atoms?', 'Choice': {'Choice1': 'Ionic bond', 'Choice2': 'Covalent bond', 'Choice3': 'Polar bond', 'Choice4': 'Hydrogen bond'}}, 'Question5': {'Question': 'What is the name of the process by which an alkane is converted into an alkene?', 'Choice': {'Choice1': 'Dehydration', 'Choice2': 'Hydration', 'Choice3': 'Hydrogenation', 'Choice4': 'Dehydrogenation'}}, 'Question6': {'Question': 'Which of the following compounds is an alcohol?', 'Choice': {'Choice1': 'CH3CH2OH', 'Choice2': 'CH3CH2CH3', 'Choice3': 'CH3CO
# ...

# %%
import pandas as pd
df = pd.DataFrame([
    {"Question": q_info['Question'], **q_info['Choice']}
    for q_key, q_info in questions_json.items()
])

# Print the DataFrame
(df)
# Out:
#                                             Question  \
# 0  Which functional group is present in carboxyli...
# 1  What is the process of breaking down large mol...
# 2  Which type of bond is formed by the sharing of...
# 3  What is the name of the process by which an al...
# 4    Which of the following compounds is an alcohol?
# 5  What is the purpose of a catalyst in a chemica...
# 6  Which of the following is a characteristic of ...
# 7  What is the term for the movement of electrons...
# 8  Which of the following reactions involves the ...
#
#                                        Choice1  \
# 0                                          -OH
# 1                                    Synthesis
# 2                                   Ionic bond
# 3                                  Dehydration
# 4                                     CH3CH2OH
# 5  To increase the temperature of the reaction
# 6                     They are highly reactive
# 7                                    Resonance
# ...

# %%
#Create content 
Topic = "create a chat gpt"
Prompt = f"""You are a planner teacher for student learning. The Student want to learn how to {Topic}. So Create a guideline that their should study skill or knowledge before {Topic} 
.Create 10 learning path and write the Answer in the Json format and Thai Language 

'Learning1' : ['Topic' :'q1',
                    'detail' : 'd1'
                ],
                    
'Learning2' : 'Topic' :'q2',
                'detail' : 'd2'
                ]
"""
print(Prompt)
# Out:
# You are a planner teacher for student learning. The Student want to learn how to create a chat gpt. So Create a guideline that their should study skill or knowledge before create a chat gpt
# .Create 10 learning path and write the Answer in the Json format and Thai Language
#
# 'Learning1' : ['Topic' :'q1',
#                     'detail' : 'd1'
#                 ],
#
# 'Learning2' : 'Topic' :'q2',
#                 'detail' : 'd2'
#                 ]

# %%
import json
Answer = """{
  'Learning1': {
    'Topic': 'การประมวลผลภาษาธรรมชาติ (Natural Language Processing)',
    'detail': 'เรียนรู้พื้นฐานของการประมวลผลภาษาธรรมชาติ รวมถึงเทคนิคการทำความเข้าใจและวิเคราะห์ข้อความ'
  },
  
  'Learning2': {
    'Topic': 'ทฤษฎีปัญญาประดิษฐ์ (Artificial Intelligence)',
    'detail': 'ศึกษาพื้นฐานของ AI และวิธีที่มันถูกนำมาใช้ในการเรียนรู้เชิงลึกเพื่อสร้างโมเดลแชทบอท'
  },
  
  'Learning3': {
    'Topic': 'การเรียนรู้ของเครื่อง (Machine Learning)',
    'detail': 'เข้าใจพื้นฐานของการเรียนรู้ของเครื่อง รวมถึงการใช้งานโมเดลแบบต่างๆ ในการฝึกฝนแชทบอท'
  },
  
  'Learning4': {
    'Topic': 'การเขียนโปรแกรมด้วย Python',
    'detail': 'ฝึกฝนการเขียนโปรแกรมด้วยภาษา Python ซึ่งเป็นภาษาหลักที่ใช้ในการพัฒนาโมเดล AI'
  },
  
  'Learning5': {
    'Topic': 'การใช้งาน API ของ GPT',
    'detail': 'เรียนรู้การใช้ OpenAI API เพื่อเชื่อมต่อและใช้งาน GPT ในการสร้างแชทบอท'
  }
}
"""

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\Acer\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import json

Answer = Answer.replace("'",'"')
print(Answer)
LearningPath = json.loads(Answer)

df = pd.DataFrame([
    # {"Topic": q_info['Topic'], **q_info['detail']}
    {"Topic": q_info['Topic'],"detail": q_info['detail']}
    for q_key, q_info in LearningPath.items()
])

# Print the DataFrame
(df)
# Out:
# {
#   "Learning1": {
#     "Topic": "การประมวลผลภาษาธรรมชาติ (Natural Language Processing)",
#     "detail": "เรียนรู้พื้นฐานของการประมวลผลภาษาธรรมชาติ รวมถึงเทคนิคการทำความเข้าใจและวิเคราะห์ข้อความ"
#   },
#
#   "Learning2": {
#     "Topic": "ทฤษฎีปัญญาประดิษฐ์ (Artificial Intelligence)",
#     "detail": "ศึกษาพื้นฐานของ AI และวิธีที่มันถูกนำมาใช้ในการเรียนรู้เชิงลึกเพื่อสร้างโมเดลแชทบอท"
#   },
#
#   "Learning3": {
#     "Topic": "การเรียนรู้ของเครื่อง (Machine Learning)",
#     "detail": "เข้าใจพื้นฐานของการเรียนรู้ของเครื่อง รวมถึงการใช้งานโมเดลแบบต่างๆ ในการฝึกฝนแชทบอท"
#   },
#
#   "Learning4": {
#     "Topic": "การเขียนโปรแกรมด้วย Python",
#     "detail": "ฝึกฝนการเขียนโปรแกรมด้วยภาษา Python ซึ่งเป็นภาษาหลักที่ใช้ในการพัฒนาโมเดล AI"
#   },
#
#   "Learning5": {
#     "Topic": "การใช้งาน API ของ GPT",
#     "detail": "เรียนรู้การใช้ OpenAI API เพื่อเชื่อมต่อและใช้งาน GPT ในการสร้างแชทบอท"
#   }
# }
#                                                Topic  \
# ...
