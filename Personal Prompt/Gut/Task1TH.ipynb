# %%
#Task1
#CreateContent
Personal = "ผู้จัดการเนื้อหาการเรียนที่สามารถจัดเนื้อหาได้ทุกเนื้อหาบนโลกใบนี้และเนื้อหาที่คุณจัดจะเหมาะสมกับเวลาที่ผู้เรียนมี"
Topic = "การเรียน Python ตั้งแต่พื้นฐานไปขั้นสูง"
Detail = "แบ่งเนื้อหาทั้งหมดที่ต้องเรียนเป็นหลายๆระดับ เนื้อหาที่ง่ายจะอยู่ระดับต่ำ เนื้อหาที่ยากจะอยู่ระดับสูง จากนั้นบอกเวลาที่ต้องใช้ในแต่ละเนื้อหาให้เหมาะสมตามเวลาที่ผู้เรียนมี "
Time = "1เดือน"

Prompt = f"""คุณคือ{Personal}ผู้เรียนต้องการให้คุณจัดเนื้อหาสำหรับ{Topic}ภายในเวลา{Time}โดยคุณจะต้อง{Detail} โดยตอบในรูปแบบของ JSON และเป็นภาษาไทยในรูปแบบ
[เรื่องที่ต้องการเรียน]
"ระดับง่าย":{{
    "เนื้อหา"{{
       "เนื้อหา 1" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 2" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 3" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 4" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       ...
    }}
}},
"ระดับกลาง":{{
    "เนื้อหา"{{
       "เนื้อหา 1" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 2" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 3" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 4" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       ...
    }}
}},
"ระดับยาก":{{
    "เนื้อหา"{{
       "เนื้อหา 1" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 2" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 3" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 4" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       ...
    }}
}}
"""

print(Prompt)
# Out:
# คุณคือผู้จัดการเนื้อหาการเรียนที่สามารถจัดเนื้อหาได้ทุกเนื้อหาบนโลกใบนี้และเนื้อหาที่คุณจัดจะเหมาะสมกับเวลาที่ผู้เรียนมีผู้เรียนต้องการให้คุณจัดเนื้อหาสำหรับการเรียน Python ตั้งแต่พื้นฐานไปขั้นสูงภายในเวลา1เดือนโดยคุณจะต้องแบ่งเนื้อหาทั้งหมดที่ต้องเรียนเป็นหลายๆระดับ เนื้อหาที่ง่ายจะอยู่ระดับต่ำ เนื้อหาที่ยากจะอยู่ระดับสูง จากนั้นบอกเวลาที่ต้องใช้ในแต่ละเนื้อหาให้เหมาะสมตามเวลาที่ผู้เรียนมี  โดยตอบในรูปแบบของ JSON และเป็นภาษาไทยในรูปแบบ
# [เรื่องที่ต้องการเรียน]
# "ระดับง่าย":{
#     "เนื้อหา"{
#        "เนื้อหา 1" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
#        "เนื้อหา 2" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
#        "เนื้อหา 3" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
#        "เนื้อหา 4" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
#        ...
#     }
# },
# "ระดับกลาง":{
#     "เนื้อหา"{
#        "เนื้อหา 1" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
#        "เนื้อหา 2" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
#        "เนื้อหา 3" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
# ...

# %%
import pandas as pd
text = """

    [การเรียน Python]
    [ระดับง่าย]
    1. การติดตั้ง Python และการเข้าใจสภาพแวดล้อมในการพัฒนา (IDE) ใช้เวลา 2 ชั่วโมง
    2. พื้นฐานของภาษา Python: ประเภทข้อมูล, ตัวแปร, และการแสดงผลลัพธ์ ใช้เวลา 4 ชั่วโมง
    3. การทำงานกับ strings และ lists ใน Python ใช้เวลา 4 ชั่วโมง
    4. การทำงานกับฟังก์ชันใน Python ใช้เวลา 4 ชั่วโมง
    5. การทำงานกับเงื่อนไขและการวนซ้ำใน Python ใช้เวลา 6 ชั่วโมง

    [ระดับกลาง]
    1. การทำงานกับ dictionaries และ sets ใน Python ใช้เวลา 4 ชั่วโมง
    2. การทำงานกับ object-oriented programming (OOP) ใน Python ใช้เวลา 6 ชั่วโมง
    3. การทำงานกับไฟล์และการอ่าน/เขียนข้อมูลใน Python ใช้เวลา 4 ชั่วโมง
    4. การทำงานกับ modules และ packages ใน Python ใช้เวลา 4 ชั่วโมง
    5. การทำงานกับการจัดการข้อผิดพลาดใน Python ใช้เวลา 4 ชั่วโมง

    [ระดับยาก]
    1. การทำงานกับ asynchronous programming ใน Python ใช้เวลา 6 ชั่วโมง
    2. การทำงานกับ decorators และ generators ใน Python ใช้เวลา 6 ชั่วโมง
    3. การทำงานกับ regular expressions ใน Python ใช้เวลา 6 ชั่วโมง
    4. การทำงานกับ data structures และ algorithms ใน Python ใช้เวลา 8 ชั่วโมง
    5. การทำงานกับ web development ด้วย Flask หรือ Django ใช้เวลา 12 ชั่วโมง

    """
df = pd.DataFrame([])
