# %%
import os 
try: 
    import torch
    import pandas as pd 
    import json
    import requests
except:
    os.system('pip install torch pandas requests')
    import torch
    import pandas as pd 
    import json
    import requests

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

def ReturnJsonFormat(Text_Json_format,replace=False):
    if replace:
        Text_Json_format = Text_Json_format.replace("'",'"').replace('[','}').replace(']','}')
    return json.loads(Text_Json_format)

#Typhoon API typhoon-v1.5x-70b-instruct
#Huggingface Model "scb10x/llama-3-typhoon-v1.5x-70b-instruct"
def QueryTyphoon_70b(Prompt,device='cuda'):
    endpoint = 'https://api.opentyphoon.ai/v1/chat/completions'
    res = requests.post(endpoint, json={
        "model": "typhoon-v1.5x-70b-instruct",
        "max_tokens": 1024,
        "messages":  [{"content": Prompt ,"role":"user"}],
        "temperature": 0.3,
        "top_p": 0.9,
        "top_k": 0,
        "repetition_penalty": 1.05,
        "min_p": 0
    }, headers={
        "Authorization": "Bearer sk-iUg6tDp6sZt1TtK69ZWEm9PTHhfPC0yo8ktw2OuyX4q9TOPr",
    })
    data = res.json()
    queries = data["choices"][0]["message"]["content"]
    queries = queries.replace("%d.","")
    return queries
# Out:
# Using device: cpu

# %%
Topic = "create a chat gpt"
Persona = "greatest planner teacher for student learning"
Time = "24 hour"
#==========================================================================

Prompt_Task1 = f"""You are a planner teacher for student learning. The Student want to learn how to {Topic}. So Create a guideline that he should study skill or knowledge before {Topic} 
write the Answer in the Json format and English Language. And do not mention to the title of content just only Json format for the response 

'Learning1' : ['Topic' :'q1',
                    'detail' : 'd1'
                ],
                    
'Learning2' : 'Topic' :'q2',
                'detail' : 'd2'
                ]
"""

# %%
answer_task1 = QueryTyphoon_70b(Prompt_Task1) #Query 1 
queries_task1 = ReturnJsonFormat(answer_task1,replace=True)
df_task1 = pd.DataFrame([
    {"Topic": q_info['Topic'],"detail": q_info['detail']}
    for q_key, q_info in queries_task1.items()
])
print(df_task1)
# Out:
#                                Topic  \
# 0                 Python Programming
# 1            Machine Learning Basics
# 2             Deep Learning Concepts
# 3  Natural Language Processing (NLP)
# 4           Transformer Architecture
# 5                          GPT Model
# 6                Dataset Preparation
# 7      Model Training and Evaluation
# 8         Deployment and Integration
#
#                                               detail
# 0  Understanding of Python programming language, ...
# 1  Fundamentals of machine learning, including su...
# 2  Understanding of deep learning concepts, such ...
# 3  Knowledge of NLP techniques, including text pr...
# 4  In-depth understanding of the transformer arch...
# 5  Familiarity with the GPT (Generative Pre-train...
# 6  Understanding of how to prepare and preprocess...
# 7  Knowledge of training GPT models using large d...
# 8  Understanding of how to deploy trained chat GP...

# %%
df_task1
# Out:
#                                Topic  \
# 0                 Python Programming
# 1            Machine Learning Basics
# 2             Deep Learning Concepts
# 3  Natural Language Processing (NLP)
# 4           Transformer Architecture
# 5                          GPT Model
# 6                Dataset Preparation
# 7      Model Training and Evaluation
# 8         Deployment and Integration
#
#                                               detail
# 0  Understanding of Python programming language, ...
# 1  Fundamentals of machine learning, including su...
# 2  Understanding of deep learning concepts, such ...
# 3  Knowledge of NLP techniques, including text pr...
# 4  In-depth understanding of the transformer arch...
# 5  Familiarity with the GPT (Generative Pre-train...
# 6  Understanding of how to prepare and preprocess...
# 7  Knowledge of training GPT models using large d...
# 8  Understanding of how to deploy trained chat GP...

# %%
Personal = "ผู้จัดการเนื้อหาการเรียนที่สามารถจัดเนื้อหาได้ทุกเนื้อหาบนโลกใบนี้และเนื้อหาที่คุณจัดจะเหมาะสมกับเวลาที่ผู้เรียนมี"
Topic = "การเรียน Python ตั้งแต่พื้นฐานไปขั้นสูง"
Detail = "แบ่งเนื้อหาทั้งหมดที่ต้องเรียนเป็นหลายๆระดับ เนื้อหาที่ง่ายจะอยู่ระดับต่ำ เนื้อหาที่ยากจะอยู่ระดับสูง จากนั้นบอกเวลาที่ต้องใช้ในแต่ละเนื้อหาให้เหมาะสมตามเวลาที่ผู้เรียนมี "
Time = "1เดือน"

Prompt_Task1 = f"""คุณคือ{Personal}ผู้เรียนต้องการให้คุณจัดเนื้อหาสำหรับ{Topic}ภายในเวลา{Time}โดยคุณจะต้อง{Detail} โดยตอบในรูปแบบของ JSON และเป็นภาษาไทยในรูปแบบ
[เรื่องที่ต้องการเรียน]
"ระดับง่าย":{{
    "เนื้อหา"{{
       "เนื้อหา 1" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 2" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 3" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 4" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       ...
    }}
}},
"ระดับกลาง":{{
    "เนื้อหา"{{
       "เนื้อหา 1" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 2" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 3" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 4" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       ...
    }}
}},
"ระดับยาก":{{
    "เนื้อหา"{{
       "เนื้อหา 1" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 2" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 3" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       "เนื้อหา 4" : "เวลาที่ต้องใช้ในการเรียนเนื้อหา"
       ...
    }}
}}
"""

# %%
answer_task1 = QueryTyphoon_70b(Prompt_Task1) #Task1 จัดเนื้อหาที่จะต้องเรียน
print(answer_task1)
# Out:
# "Python จากพื้นฐานถึงขั้นสูงใน 1 เดือน": {
#     "ระดับง่าย": {
#         "เนื้อหา": {
#             "การแนะนำ Python และการติดตั้ง": "2 ชั่วโมง",
#             "การพิมพ์ข้อความและตัวแปร": "2 ชั่วโมง",
#             "การทำความเข้าใจเกี่ยวกับประเภทข้อมูล": "2 ชั่วโมง",
#             "การใช้งาน Operator และ Expressions": "2 ชั่วโมง",
#             "การเขียนโปรแกรมแบบ Sequential": "2 ชั่วโมง"
#         }
#     },
#     "ระดับกลาง": {
#         "เนื้อหา": {
#             "การใช้งาน Control Structures (if, for, while loop)": "4 ชั่วโมง",
#             "การใช้งาน Functions และ Modules": "4 ชั่วโมง",
#             "การใช้งาน Lists และ Tuples": "4 ชั่วโมง",
#             "การใช้งาน Dictionaries และ Sets": "4 ชั่วโมง",
#             "การใช้งาน File Input/Output": "4 ชั่วโมง"
#         }
#     },
#     "ระดับยาก": {
#         "เนื้อหา": {
#             "การใช้งาน Object-Oriented Programming (OOP) Concepts": "6 ชั่วโมง",
#             "การใช้งาน Exception Handling และ Debugging": "6 ชั่วโมง",
# ...

# %%
import json
Question = """
{
    "ระดับง่าย": {
        "เนื้อหา": {
            "การแนะนำ Python และการติดตั้ง": "2 ชั่วโมง",
            "การพิมพ์ข้อความและตัวแปร": "2 ชั่วโมง",
            "การทำความเข้าใจเกี่ยวกับประเภทข้อมูล": "2 ชั่วโมง",
            "การใช้งาน Operator และ Expressions": "2 ชั่วโมง",
            "การเขียนโปรแกรมแบบ Sequential": "2 ชั่วโมง"
        }
    },
    "ระดับกลาง": {
        "เนื้อหา": {
            "การใช้งาน Control Structures (if, for, while loop)": "4 ชั่วโมง",
            "การใช้งาน Functions และ Modules": "4 ชั่วโมง",
            "การใช้งาน Lists และ Tuples": "4 ชั่วโมง",
            "การใช้งาน Dictionaries และ Sets": "4 ชั่วโมง",
            "การใช้งาน File Input/Output": "4 ชั่วโมง"
        }
    },
    "ระดับยาก": {
        "เนื้อหา": {
            "การใช้งาน Object-Oriented Programming (OOP) Concepts": "6 ชั่วโมง",
            "การใช้งาน Exception Handling และ Debugging": "6 ชั่วโมง",
            "การใช้งาน Regular Expressions (regex)": "6 ชั่วโมง",
            "การใช้งาน Web Development Frameworks (Flask, Django)": "8 ชั่วโมง",
            "การใช้งาน Data Analysis Libraries (Pandas, NumPy, Matplotlib)": "8 ชั่วโมง"
        }
    }
}
"""

# %%
QuestionJson = json.loads(Question)
print(QuestionJson)
# Out:
# {'ระดับง่าย': {'เนื้อหา': {'การแนะนำ Python และการติดตั้ง': '2 ชั่วโมง', 'การพิมพ์ข้อความและตัวแปร': '2 ชั่วโมง', 'การทำความเข้าใจเกี่ยวกับประเภทข้อมูล': '2 ชั่วโมง', 'การใช้งาน Operator และ Expressions': '2 ชั่วโมง', 'การเขียนโปรแกรมแบบ Sequential': '2 ชั่วโมง'}}, 'ระดับกลาง': {'เนื้อหา': {'การใช้งาน Control Structures (if, for, while loop)': '4 ชั่วโมง', 'การใช้งาน Functions และ Modules': '4 ชั่วโมง', 'การใช้งาน Lists และ Tuples': '4 ชั่วโมง', 'การใช้งาน Dictionaries และ Sets': '4 ชั่วโมง', 'การใช้งาน File Input/Output': '4 ชั่วโมง'}}, 'ระดับยาก': {'เนื้อหา': {'การใช้งาน Object-Oriented Programming (OOP) Concepts': '6 ชั่วโมง', 'การใช้งาน Exception Handling และ Debugging': '6 ชั่วโมง', 'การใช้งาน Regular Expressions (regex)': '6 ชั่วโมง', 'การใช้งาน Web Development Frameworks (Flask, Django)': '8 ชั่วโมง', 'การใช้งาน Data Analysis Libraries (Pandas, NumPy, Matplotlib)': '8 ชั่วโมง'}}}

# %%
import pandas as pd
rows = []
for level, contents in QuestionJson.items():
    for topic, time in contents['เนื้อหา'].items():
        rows.append([level, topic, time])

df = pd.DataFrame(rows, columns=['ระดับ', 'เนื้อหา', 'ระยะเวลา'])

df
# Out:
#         ระดับ                                            เนื้อหา   ระยะเวลา
# 0   ระดับง่าย                      การแนะนำ Python และการติดตั้ง  2 ชั่วโมง
# 1   ระดับง่าย                           การพิมพ์ข้อความและตัวแปร  2 ชั่วโมง
# 2   ระดับง่าย               การทำความเข้าใจเกี่ยวกับประเภทข้อมูล  2 ชั่วโมง
# 3   ระดับง่าย                 การใช้งาน Operator และ Expressions  2 ชั่วโมง
# 4   ระดับง่าย                      การเขียนโปรแกรมแบบ Sequential  2 ชั่วโมง
# 5   ระดับกลาง  การใช้งาน Control Structures (if, for, while l...  4 ชั่วโมง
# 6   ระดับกลาง                    การใช้งาน Functions และ Modules  4 ชั่วโมง
# 7   ระดับกลาง                         การใช้งาน Lists และ Tuples  4 ชั่วโมง
# 8   ระดับกลาง                    การใช้งาน Dictionaries และ Sets  4 ชั่วโมง
# 9   ระดับกลาง                        การใช้งาน File Input/Output  4 ชั่วโมง
# 10   ระดับยาก  การใช้งาน Object-Oriented Programming (OOP) Co...  6 ชั่วโมง
# ...
