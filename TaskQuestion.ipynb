# %%
Topic = "Question for test student who planner about learning Logical Math in one week"
Prompt = f"""
You are a greatest teacher for create 10 exercises,
one day you got request from student about them plan so you want to create {Topic} to Level measurement
write the Answer in the Json format and English Language 

'Question1' : ['Question' :'q1',
                    'Choice' : [
                        'Choice1' : 'q1',
                        'Choice2' : 'q1',
                        'Choice3' : 'q1',
                        'Choice4' : 'q1'
                    ]],
                    
    'Question2' : ['Question' :'q2',
                    'Choice' : [
                        'Choice1' : 'q2',
                        'Choice2' : 'q2',
                        'Choice3' : 'q2',
                        'Choice4' : 'q2'
                    ]],

"""
print(Prompt)
# Out:
# You are a greatest teacher for create 10 exercises,
# one day you got request from student about them plan so you want to create Question for test student who planner about learning Logical Math in one week to Level measurement
# write the Answer in the Json format and English Language
#
# 'Question1' : ['Question' :'q1',
#                     'Choice' : [
#                         'Choice1' : 'q1',
#                         'Choice2' : 'q1',
#                         'Choice3' : 'q1',
#                         'Choice4' : 'q1'
#                     ]],
#
#     'Question2' : ['Question' :'q2',
#                     'Choice' : [
#                         'Choice1' : 'q2',
#                         'Choice2' : 'q2',
#                         'Choice3' : 'q2',
#                         'Choice4' : 'q2'
#                     ]],

# %%
import json
Question = """
{
  "Question1": {
    "Question": "Which of the following is a logical operator?",
    "Choice": {
      "Choice1": "AND",
      "Choice2": "SUM",
      "Choice3": "MULTIPLY",
      "Choice4": "DIVIDE"
    }
  },
  "Question2": {
    "Question": "What is the result of TRUE AND FALSE?",
    "Choice": {
      "Choice1": "TRUE",
      "Choice2": "FALSE",
      "Choice3": "1",
      "Choice4": "0"
    }
  },
  "Question3": {
    "Question": "Which of the following is an example of a tautology in logic?",
    "Choice": {
      "Choice1": "A AND NOT A",
      "Choice2": "A OR NOT A",
      "Choice3": "A AND B",
      "Choice4": "A OR B"
    }
  },
  "Question4": {
    "Question": "What is De Morgan's law in logic?",
    "Choice": {
      "Choice1": "NOT (A OR B) = (NOT A) AND (NOT B)",
      "Choice2": "A AND B = A OR B",
      "Choice3": "NOT (A AND B) = (NOT A) AND B",
      "Choice4": "A OR (NOT B) = B"
    }
  },
  "Question5": {
    "Question": "What does the logical implication A → B mean?",
    "Choice": {
      "Choice1": "If A is true, B must be false",
      "Choice2": "If A is false, B must be true",
      "Choice3": "If A is true, B must be true",
      "Choice4": "If A is false, B must be false"
    }
  },
  "Question6": {
    "Question": "What is the negation of the statement 'All students are present'?",
    "Choice": {
      "Choice1": "No students are present",
      "Choice2": "Some students are not present",
      "Choice3": "Some students are present",
      "Choice4": "No students are absent"
    }
  },
  "Question7": {
    "Question": "What does the XOR (exclusive OR) operator return when both inputs are TRUE?",
    "Choice": {
      "Choice1": "TRUE",
      "Choice2": "FALSE",
      "Choice3": "1",
      "Choice4": "It depends"
    }
  },
  "Question8": {
    "Question": "In propositional logic, which of the following is a valid conclusion?",
    "Choice": {
      "Choice1": "P AND NOT P",
      "Choice2": "P OR NOT P",
      "Choice3": "P → P",
      "Choice4": "P ↔ P"
    }
  },
  "Question9": {
    "Question": "What is a contradiction in logical terms?",
    "Choice": {
      "Choice1": "A statement that is always false",
      "Choice2": "A statement that is always true",
      "Choice3": "A statement that can be true or false",
      "Choice4": "A statement that is sometimes true"
    }
  },
  "Question10": {
    "Question": "What is the truth value of the statement 'If 1 is greater than 2, then 3 equals 3'?",
    "Choice": {
      "Choice1": "TRUE",
      "Choice2": "FALSE",
      "Choice3": "UNDEFINED",
      "Choice4": "It depends on the context"
    }
  }
}
"""

# %%
Questions_json = json.loads(Question)
print(Questions_json)
# Out:
# {'Question1': {'Question': 'Which of the following is a logical operator?', 'Choice': {'Choice1': 'AND', 'Choice2': 'SUM', 'Choice3': 'MULTIPLY', 'Choice4': 'DIVIDE'}}, 'Question2': {'Question': 'What is the result of TRUE AND FALSE?', 'Choice': {'Choice1': 'TRUE', 'Choice2': 'FALSE', 'Choice3': '1', 'Choice4': '0'}}, 'Question3': {'Question': 'Which of the following is an example of a tautology in logic?', 'Choice': {'Choice1': 'A AND NOT A', 'Choice2': 'A OR NOT A', 'Choice3': 'A AND B', 'Choice4': 'A OR B'}}, 'Question4': {'Question': "What is De Morgan's law in logic?", 'Choice': {'Choice1': 'NOT (A OR B) = (NOT A) AND (NOT B)', 'Choice2': 'A AND B = A OR B', 'Choice3': 'NOT (A AND B) = (NOT A) AND B', 'Choice4': 'A OR (NOT B) = B'}}, 'Question5': {'Question': 'What does the logical implication A → B mean?', 'Choice': {'Choice1': 'If A is true, B must be false', 'Choice2': 'If A is false, B must be true', 'Choice3': 'If A is true, B must be true', 'Choice4': 'If A is false, B mus
# ...

# %%
import pandas as pd
df = pd.DataFrame([
    {"Question": q_info['Question'], **q_info['Choice']}
    for q_key, q_info in Questions_json.items()
])

# Print the DataFrame
(df)
# Out:
#                                             Question  \
# 0      Which of the following is a logical operator?
# 1              What is the result of TRUE AND FALSE?
# 2  Which of the following is an example of a taut...
# 3                  What is De Morgan's law in logic?
# 4      What does the logical implication A → B mean?
# 5  What is the negation of the statement 'All stu...
# 6  What does the XOR (exclusive OR) operator retu...
# 7  In propositional logic, which of the following...
# 8          What is a contradiction in logical terms?
# 9  What is the truth value of the statement 'If 1...
#
#                               Choice1                          Choice2  \
# 0                                 AND                              SUM
# 1                                TRUE                            FALSE
# 2                         A AND NOT A                       A OR NOT A
# 3  NOT (A OR B) = (NOT A) AND (NOT B)                 A AND B = A OR B
# ...
